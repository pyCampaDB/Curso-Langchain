# %% [markdown]
# # Objetivo
#
# Extraer info relevante de archivos financieros, como son las llamadas trimestrales de ganancias de una empresa. Para ello, se plantean tres tareas principales:
#
# 1. `Extracción de entidades`: Se identifican entidades como personas, lugares y empresas, así como sus atributos, como roles o relaciones.
#     1. Es una tarea de entity-extraction
# 2. `Identificación de enventos relevantes`: Se identifican eventos relevantes en el texto y se clasifican como positivos o negativos.
#     1. Es una tarea que mezcla summarization con sentiment analysis.
# 3. `Búsqueda de información`: Se construye un pipeline para hacer preguntas al texto.
#     1. Es una tarea de Question answering con RAG
#
# No disponemos de un modelo especializado para este tipo de tareas ni de una gran db con la que pre-entrenar un modelo. Por ello, vamos a utilizar un LLM de gran tamaño, como GPT-3, como pto de partida.
#
# En este caso, no se realizará fine-tuning del modelo, sino que se trabajará con el modelo base. Se experimentará con diferentes prompts y con el acercamiento RAG.
#
#
#
# ### `Sumario`
#
# 1. Preparar los datos
#     * Cargar el doc
#     * Dividir en párrafos
#     * Contar nº de tokens por párrafo
#
# 2. Extraer entidades y relaciones
#     * Preparar el prompt
#     * Correr el prompt por el LLM
#     * Formatear la salida
#     * Comentarios
#
# 3. Identificar eventos relevantes
#     * Preparar el prompt
#     * Correr el prompt por el LLM
#     * Formatear la salida
#     * Comentarios
#
# 4. Obtener info mediante preguntas:
#     * Modelo de embeddings
#     * DB vectorial
#     * Retrieval
#     * Generation
#     * Comentarios

# %%
from os import getenv, getcwd
from dotenv import load_dotenv
from langchain_openai import OpenAI


load_dotenv()

model = 'gpt-3.5-turbo-instruct'




max_tokens = 1000

llm = OpenAI(openai_api_key=getenv('OPEN_API_KEY', ''),
                 model= model,
                 temperature=0)

llm.max_tokens = max_tokens

# %%
from langchain.document_loaders import TextLoader
from os import getcwd
print(f"{getcwd()}\\assets\\growth_point_properties.md")

loader = TextLoader(f"{getcwd()}\\assets\\growth_point_properties.md")

docs = loader.load()
# Out:
# d:\Escritorio\Python Studio\Open Webinars\Langchain\proyecto final\assets\growth_point_properties.md

# %% [markdown]
# ## 1.2 - Dividir en párrafos
#
# En este caso voy a utilizar un método propio para dividir el texto en vez de utilizar un textsplitter de LangChain. La razón es que el texto parece estar mal formateado y un splitter normal no funcionaria como yo quiero.
#
# Para identificar párrafos, `usamos una expresion linear que divide el texto cuando se encuentra un salto de línea \n seguido de una palabra mayúscula`.
#
# Una mejor alternativa, sobretodo si vamos a tratar con múltiples documentos, sería preformattear el texto o buscar fuentes alternativas del mismo que si esten bien formateadas. ein embargo, vamos a considerar este ejercicio como una "Prueba de Concepto" y por ello, vamos a seguir un acercamiento más simple, trabajando directamente sobre el documento proporcionado.

# %%
from re import split as reSplit

def extract_paragraphs_from_txt(docs):
    paragraphs = []
    # Iteramos por cada pág del texto
    for page in docs:
        page_text = page.page_content

        #Usamos una expresión regular para identificar párrafos como aquellas lineas que empiezan por "\n" y luego una letra mayúscula
        page_paragraphs = reSplit(r'\n(?=[A-Z])', page_text)

        #Eliminamos párrafos vacíos
        page_paragraphs = [p.strip() for p in page_paragraphs if p.strip()]

        #Añadimos el párrafo a la lista
        paragraphs.extend(page_paragraphs)
    return paragraphs

#Dividimos el texto en párrafos
paragraphs = extract_paragraphs_from_txt(docs)

#Ahora "paragraphs" es una lista de strings, donde cada string es un párrafo
cleaned_paragraphs = [paragraph.replace('\n', '') for paragraph in paragraphs]

#Ahora añadimos un salto de página al inicio de cada párrafo para cuando utilicemos esta informacion en los prompts
cleaned_paragraphs = ['\n' + p for p in paragraphs]

cleaned_paragraphs
# Out:
# ['\nGrowthpoint Properties Australia: Q4 2023 Earnings Call',
#  '\nThank you for standing by and welcome to the Growthpoint Properties Australia FY 2023',
#  '\nResults. All participants are in a listen-only mode. There will be a presentation followed by a\nquestion-and-answer session.',
#  '\nI would now like to hand the conference over to Mr. Timothy Collyer, Managing Director. Please\ngo ahead.',
#  '\nGood morning, and welcome to Growthpoint Properties Australia full year 2023 results. My\nname is Tim Collyer, Managing Director of Growthpoint. Joining me this morning are Michael',
#  '\nGreen, Chief Investment Officer; and Dion Andrews, Chief Financial Officer. I will start this\nmorning with a brief overview of our results and strategy. Michael will then provide an update on\nour property portfolio followed by Dion, who will give a more detailed review of our financials.',
#  "\nAnd finally, I'll provide a summary and outlook. We will then be happy to answer any questions\nyou may have.",
#  "\nTurning to slide 4. Our goal remains to provide securityholders with sustainable income returns\nand capital appreciation over the long-term. Growthpoint has a long track record of delivering\nthe value by investing in high quality assets to maximize value for securityholders. In financial\nyear 2023, we purchased the GSO building in Dandenong with a 9.4-year WALE and divested\n333 Ann Street, Brisbane with a 3.7-year WALE. The group's leasing performance was strong,\nwith over 156,000 square meters leased equivalent to 11.2% of income, resulting in occupancy\nof 93% across the portfolio. We have also successfully completed the integration of the Fortius",
#  '\nFunds Management platform, which we acquired in September 2022.',
#  '\nLastly, capital management remains a sharp (00:02:26) focus given the high interest rate\nenvironment. Our gearing will remain at the low-end of the target range, and we also completed\nthe securities buyback program in May.',
#  '\nTurning to slide 5 and to our long-term portfolio metrics and a reminder of the stable long-term\nnature of the GOZ portfolio. The portfolio is underpinned by a long WALE and high occupancy,\nwhich has been consistent with the last 10 years.',
#  "\nTurning to slide 6 and the financial year 2023 overview. I'm pleased to be able to present\nanother solid year for the group, despite challenging market conditions. FFO was lower but\nabove initial guidance provided at the financial year 2022 results, of AUD 0.25 to AUD 0.26 per\nsecurity. Distributions declared for the period were up 2.9%. This was a great outcome given the\nhigher interest rates experienced throughout the financial year 2023.",
#  "\nAs a result of higher interest rates and consequential impact on capitalization and discount\nrates, the group's property portfolio value decreased by 6.5% on a like-for-like basis over 12\nmonths. This was a primary driver of the lower NTA. In funds management, we recorded AUD\n1.8 billion of FUM, which is slightly down from the AUD 1.9 billion of FUM upon acquisition,\nwhich I will expand upon later.",
#  '\nTurning to slide 7 on metro and fringe CBD office market dynamics. metro and fringe CBD office\nlocations offer a great alternative, particularly for those tenants that do not need to be in the',
#  '\nCBD. According to JLL data, the CBD office markets have grown by 1.7 million square meters\nor 10.2% over the last 10 years. Non-CBD markets have grown AUD 1.5 million square meters\nor 17% over the same period. So the metro and fringe office market have been growing more\nstrongly than CBDs reflective of tenant demand.',
#  '\nMany tenants, particularly government lag the (00:05:08) ability to occupy a building on their\nown given the security issues, and this is the case for our New South Wales property at 1',
#  '\nCharles Street, Parramatta. Across our office portfolio, we have a range of green credentials,\nhigh quality assets, close to key transport modes which are attractive to tenants.',
#  '\nFor example, the government service office in Dandenong, an A-Grade modern office asset\nlocated in a growing major urban center 30 kilometres south east of Melbourne. The asset is\nwell positioned for transport and retail amenities being approximately 400 metres from both the',
#  '\nDandenong Railway and a major regional shopping center. All in all metro office market\ndynamics and their (00:06:00) portfolio are well supported by a range of positive thematics\n(00:06:05).',
#  '\nTurning to slide 8 and some key themes within office markets. Tenants are accommodating for\nquick feasible (00:06:18) occupancy. And whilst this is still below pre-pandemic levels, more\nemployers are mandating minimum days in the office. Vacancy rates have moved higher with',
#  "\nGrowth's (00:06:32) vacancy rate is 10% and has remained consistently lower versus the\nmarkets in which it operates. We have demonstrated an ongoing ability to lease significant\namounts of the portfolio each year, reducing expiring lease (00:06:49).",
#  '\nTurning to the industrial property sector on slide 9. The positive momentum in the industrial\nmarkets continued in financial year 2023 due to a shortage of modern warehouse space across\nall markets, underpinned by growth in e-commerce and demand for supply chain infrastructure.',
#  "\nVacancy continued to fall in the group's markets as demand outstripped limited supply with the\nnational vacancy rate reaching a record low of 0.6% in June 2023. Rent growth continued over\nthe year, with most markets recording double-digit growth in rents.",
#  '\nMoving to slide 10 and funds management. A long-term growth platform for the group is the\nacquisition of Fortius Funds Management, which was completed in September 2022. Fortius is\na property fund manager with a 30-year plus track record of delivering strong returns to its\ninvestors. During the period we successfully integrated Fortius and we are now operating as\none business. Despite challenging transaction market conditions which impacted our ability to\ngrow FUM, we have been active but diligent. There remains good appetite from investors for the\nrisk-adjusted investment returns. You can also see on the slide 2 of the funds divested assets,\nproviding excellent returns for investors. And this was the main driver of the declining funds\nsince acquisition. We are most excited about the prospects for the funds management business\nand are pleased to be working with a fantastic team that has a clear focus on growth and\ngenerating strong investor returns.',
#  "\nTurning to slide 11, and the macro environment. Whilst interest rates may still increase, it's fair\nto say that they are unlikely to appreciate what they (00:09:11) have in the past year. The\nfutures market at this time is indicating the cash rate is closer to the peak. Inflation, while still\nhigh, is abating, and unemployment remains resilient in spite of higher interest rates. Population\ngrowth remains strong and Australia still leads the way in this regard, which is a positive for\nindustrial office and retail real estate.",
#  "\nI'll now hand over to Michael for a more detailed look at the portfolio.",
#  '\nThank you, Tim. And good morning, all. Starting on slide 13 with a brief overview of our\nportfolio, which has remained largely stable over the year. Early in the financial year, we\nacquired the government services office building in Dandenong, a modern, long WALE Victorian',
#  "\nGovernment tenanted building located in Melbourne's south eastern expansion corridor power.",
#  '\nThis acquisition, predominantly funded by the divestment of 333 Ann Street, a CBD Brisbane\nasset which were acquired back in 2012 for AUD 109 million. And we have actively asset\nmanaged that asset over the last decade.',
#  '\nThe Growthpoint AUD 4.8 billion balance sheet portfolio consists of the modern office and\nindustrial assets, which are principally leased to government listed and large private tenants and\nprovide the bedrock of a resilient cash flow for our securityholders.',
#  "\nOn slide 14, we highlight the key office and industrial portfolio metrics. Increased interest rates\nhave negatively impacted on the group's valuations over the year, with cap rate expansion\nbeing exhibited across the portfolio. The group's office portfolio is reduced by 9.4% on a like-forlike basis over the year. Growthpoint's industrial portfolio valuations only have witnessed a slight\ndecline, with the 70 basis points of yield expansion being largely offset by strong market rental\ngrowth.",
#  '\nOffice occupancy is lower and the year-to-year decline is primarily attributable to the vacancy of\n(00:11:24) 5 Murray Rose Avenue in Sydney Olympic Park, accounting for 3% of the office\nportfolio income. The leasing campaign is progressing with the 6 stars NABERS rated building\nand positively viewed by prospective tenants. It is important to remember that we have received\na surrender payment from the tenant, which is reflected in the accounts this year as the lease\nwas due to expire in April 2024.',
#  '\nDion will expand on this later. The WALE has remained stable across the portfolio at 6 years.',
#  '\nThe office portfolio WALE, 6.3 years continues to underpin the resilience of the portfolio. On\nslide 15, our portfolio is exemplified by secure tenants with long leases with positive industry\nfundamentals. 40% of our office portfolio income is derived from government tenants. Our high\nquality, energy efficient buildings are attractive for government tenants, and importantly, in this\nperiod of uncertainty, the WALE of our government office tenants is 10.3 years. Tenant\nengagement is a major focus for Growthpoint, and this has been reflected by achieving industry\nleading tenant satisfaction results in the independent annual tenant survey.',
#  '\nMoving to slide 16, and the leasing activity during the year. Across the office portfolio, the group\nexecuted 33 leases, accounting for approximately 32,000 square meters of space, representing\n9.2% of the office portfolio income. The group provided an average incentive of 24% across the\noffice portfolio leases signed in FY 2023. A couple of key office leasing transactions to highlight\nover the year include 8,000 square meters, which were leased to multiple government\ndepartments at our 100 Skyring Terrace, an excellent leasing outcome, de-risking the space\nwhich had unfortunately become vacant after the previous tenant, Collection House, entered\ninto voluntary administration at the end of FY 2022. Pleasingly one of our major tenants at 75',
#  '\nDorcas Street, South Melbourne, Mondelez Australia extended their 4,500 square meter lease\nto 2028.',
#  '\nWe were also active across our industrial portfolio, leasing 124,000 square meters, representing\n15.4% of the industrial portfolio income where we saw a positive average effective rental leasing\nspread of 30%. We continue to see buoyant demand for industrial space, which remains in short\nsupply. With leasing originating from a variety of industries, including pharmaceutical supply, the\nautomotive industry, clothing retailers, and third-party logistics providers. Industrial incentives\ngranted remained low at (00:14:12).',
#  "\nThe defensive characteristics of the group's portfolio illustrated on slide 17. The portfolio WALE\nreduced slightly over the year from 6.3 years to 6 years. However, we retained one of the\nlongest office portfolio WALE in the REIT sector at 6.3 years. The portfolio was 93% occupied\nwith 2% of additional leasing in advanced negotiation. Growthpoint continues to focus heavily on\nmanaging leasing risk, and we are confident in our ability to negotiate the current challenges\nwithin the office leasing market. We have a modern, highly green credentialed office portfolio,\nand we have a strong track record of leasing on average 11.8% of the Growthpoint portfolio\nannually over the last five years.",
#  '\nSwitching now to sustainability on slide 18. Our portfolio continues to achieve a high average',
#  "\nNABERS Energy rating of 5.2 stars, and we increased our GRESB score to 81, and remain a\nsector leader in our space. Progress has been made with respect to the group's 2025 net zero\ntarget through the execution of new electricity contracts, which include green power purchases.",
#  "\nGreen power will substantially contribute to achieving Growthpoint's 2025 target. We've\nsignificantly increased our onsite solar rollout with seven additional installations progressed over\nthe year. We also issued our first sustainability linked loans, which Dion will touch on.",
#  "\nI'll now hand over to Dion for the financial overview.",
#  '\nThanks, Michael. Starting on slide 20, we again highlight our solid performance delivering FFO\nof AUD 0.268 per security, a slight decrease of 3.2% on last year. Whilst down, this was a good\noutcome given the rapid increase in interest rates and subsequent impact on interest costs.',
#  '\nHowever, NPI was up mainly due to two one-offs occurring during the year, which included a\nsurrender of lease payment received in October 2022 for 5 Murray Rose Avenue in Sydney',
#  '\nOlympic Park. The lease was originally due to expire on April 2024 and the surrender payment\nenabled Growthpoint to receive the net present value of the remaining leasing cut, meaning 22\nmonths of income within the FY 2023 result. AUD 6.5 million bank guarantee payment received\nwhen Collection House entered voluntary administration in June 2022, as we received a lease\ntermination for its 8,000 square meters at our 100 Skyring Terrace, Newstead. The quality office\nspace was progressively leased in FY 2023 by two high quality government tenants and the\nproperty is now 100% occupied.',
#  '\nAt least two (00:16:58) properties had leased for all of FY 2023 as per their original lease terms,\nthen FFO would have been around AUD 0.016 per security lower. Increased operating\nexpenses, including the cost of operating the Fortius business, and generating a general cost\ninflation. We were very pleased to declare a distribution of AUD 0.214 per security, up 2.9%.',
#  "\nOn slide 21, we've highlighted the key movements in FFO and NTA per security. The key\ndrivers of the FFO decrease include a substantial increase in interest costs up AUD 30 million or\nalmost AUD 0.04 per security, which was partially offset by increased rental income and income\ncontribution from Fortius. NTA per security decreased to AUD 4, down 12.3%, which is\nconsistent with lower portfolio valuations, which in turn were driven by a significant increase of\nthe risk-free rate during FY 2023.",
#  "\nTurning to slide 22, gearing increased from 31.6% at 30 June, 2022 to 37.2%, remaining within\nthe group's target range of 35% to 45%. The increase relates to changes in portfolio valuations,\ncompletion of the share buyback, purchase of Fortius, and of the GSO in Dandenong. These\nwere partially offset by the sale of 333 Ann Street.",
#  '\nWe retain a good buffer in our target gearing range to withstand any further potential changes in\nvaluations. We also have ample headroom to our bank covenants of LCR of 60% and ICR\ngreater than 1.6 times. Our distribution payout ratio was in the middle of the target payout ratio\nrange of between 75% and 85% of FFO.',
#  "\nOn slide 23, we take a look at our capital position moving into FY 2024. As you can see, we're\nin good shape. Our weighted average cost of debt as of 30 June, 2023 was 4.6% versus 3.4%\nsame time last year and reflects the rapid increase in interest rates during the year. The group\nentered into eight new interest rate swaps for the total notional amount of AUD 280 million at a\nweighted average fixed rate of 3.48%. As of 30 June, our debt facilities had a weighted average\nremaining term to maturity of 3.4 years, and we retained AUD 300 million of undrawn bank debt\nfacilities. We have no debt maturing until FY 2025.",
#  '\nAt 30 June, 70.5% of debt is fixed for a weighted average remaining term to maturity 2.9 years.',
#  '\nICR of 3.4 times remains well above our covenant of 1.6 times. And during the year,',
#  '\nGrowthpoint diversified its funding sources by adding two new lenders with total facility limits of',
#  '\nAUD 200 million, while repaying a maturing lender with a facility limit of AUD 90 million.',
#  "\nIn February 2023, Growthpoint extended its on market securities buyback program for up to\n2.5% of issued capital. The program was completed in May 2023, having purchased 19.3 million\nsecurities for a total consideration of AUD 63.4 million. Total purchases represented an average\ndiscount for June 30, 2023 NTA of 17.9%. I'm also happy to convey that Moody's have\nreaffirmed their BAA2 rating with a stable outlook for our debt. Finally, we entered into\nsustainability linked loans, converting AUD 520 million of the group's existing debt\narrangements, and established an overarching sustainability finance governance framework.",
#  '\nInterest margin reductions are tied to the successful achievement of sustainability KPIs and\ntargets. The KPIs will be measured against reductions in Scope 1, 2, and 3 emissions and\nperformance measured against the NABERS and GRESB ratings.',
#  "\nI'll now hand back to Tim to wrap up.",
#  '\nThank you, Dion. Our investment proposition is very simple. We invest in high quality office and\nindustrial real estate. (00:21:22) management business and manage the balance sheet\nprudently. We have a strong team with deep experience and we are very committed to\ndelivering (00:21:34).',
#  '\nTurning to the current security price discount to NTA on slide 26. This is a common theme\nacross the REIT sector, and somewhat more acute with respect to office REITs and those',
#  '\nREITs with significant office sector exposure. The discount to NTA at 30th of June, 2023 implies\na 25% reduction (00:22:03) for both the office and industrial GOZ portfolios. We believe that the\ndefensive characteristics of the office portfolio being long WALE and high quality tenants, and a\nstrong industrial market with a historic low vacancy rate will be attractive to investors in a low\ngrowth environment.',
#  '\nTurning to the focus in financial year 2024. The rate of inflation has been declining since',
#  '\nDecember 2022 quarter whilst interest rate futures indicate that the official cash rate is near the\npeak. However, A-REIT prices remain at a discount to NTA. Commercial real estate transaction\nactivity remains low relative to longer term historical averages. Although volumes may increase\nas development pipelines and redemption requests require funding. Growthpoint is well placed\nto manage through the cycle with a portfolio of high quality modern assets with strong WALE\nfrom government, ASX listed, and large corporate tenants.',
#  '\nTurning to financial year 2024 guidance. Given the outlook and factoring in interest costs on\n(00:23:33) forward, we provide FFO guidance of between AUD 0.225 and AUD 0.231 per\nsecurity for financial year 2024. We also provide distribution guidance of $0.193 per security\nwhilst maintaining our FFO payout ratio in the target range of 75% to 85% at the midpoint of\nguidance. At current pricing, the financial year 2024 distribution yield is an attractive 7.3%. We\nremain committed to providing our security holders with sustainable income returns and capital\nappreciation over the longer term.',
#  '\nThank you very much for your participation today. Thank you also to the Growthpoint team for\ntheir hard work and dedication in financial year 2023. We will now open up the lines and are\nhappy to take your questions.',
#  '\nThank you. Your first question comes from Caleb Wheatley at Macquarie Group. Please go\nahead.',
#  '\nGood morning, Tim and team. Thank you for the presentation and congratulations, Tim, on your\ntenure at Growthpoint. My first question was just around the guidance, I know you mentioned\nthe $0.16 per share impact from the one-off in FY 2023. But if you reverse that at getting to an',
#  '\nFY 2023 underlying FFO of $0.252 per share, conscious cost of debt is going to be a headwind.',
#  '\nBut just trying to understand some of the other components, in order to get down to the\nguidance range, particularly with respect to things like operational expenditure, and any high\nlevel expectations on office occupancy, and industrial NPI as well, please.',
#  "\nThanks, Caleb. It's Dion here, I'll start on that one. So when we compare 2023 to 2024, there\nare two key drivers. And you're right, debt is obviously one of them. And that's a factor across\nthe REIT sector, I think. Our cost of debt at 4.6% at 30 June, we're going to average similar to\nthat across the year, and that's obviously higher than it was in 2023. So that's one factor, but\nthat's pretty common, and relatively easy to work out. The key factor, of course, is the one-offs,\nas you pointed out. Another way to think about those one-offs though, if you take 5 Murray Rose\nalone, there's 22 months' worth of rent in FY 2023, and the building is currently vacant going\ninto 2024. We do assume leasing up across the year, but there are some weaker office leasing\nmarkets in the month, so we're taking those into account. That is a very big driver of the\ncomparison of FFO.",
#  '\nAnd the other one you touched on is office vacancy. So again, we had a tenant (00:26:46) at 15',
#  "\nGreen Square Close up in Queensland and they left in May. So again we had income for 11\nmonths in FY 2023, and the building is currently Ã¢â‚¬â€œ that area, sorry, is currently vacant as we\nhead into FY 2024 and again we'll need to lease up. So there is some occupancy as well. They\nare the main drivers. Everything else is really pretty fringe operational expenses, and share\nbuyback impact, all of those, I think are relatively minor in comparison to those two driving\nfactors.",
#  '\nThank you. And just so I understand, the AUD 0.252 should be outside of the one-off. So is cost\nof debt really the difference between potentially going from AUD 0.252 to AUD 0.225.',
#  "\nYeah. That AUD 0.016 what we said there is, if the leases continued as they were, right. Or the\nrent just continued as it was that would have been a AUD 0.016 difference. That's not what\nactually happened. We got 22 months worth of rent in the case of 5 Murray Rose. So don't get\ntoo high up on the AUD 0.016, that was just meant to be a like-for-like sort of figure. The impact\nis bigger when you take into account what actually happened, then the cost of debt is the rest.",
#  "\nOkay. And sorry, just to confirm in terms of what actually happened, I guess you're referring to\noccupancy (00:28:13) opposed to what would it have been otherwise in FY 2023?",
#  "\nYeah. I think in respect of that particular transaction, it's Tim here, is you received 22 months of\nincome in one year, and in the following year you have no income until you lease the property.",
#  "\nSo there's a big swing. I think Dion is trying to point that out.",
#  '\nYes, yes.',
#  "\nIt's not a matter of deducting AUD 0.016 from the FFO result for this year.",
#  "\nOkay. (00:28:48-00:28:54) year-on-year, but that's helpful. My next question, maybe one for",
#  '\nMichael just around the office portfolio and some leasing outcomes. So conscious, there were\nthose tenant exits throughout the year. But it seems to have ticked down again from 92% in',
#  '\nMarch to 90% as at June. Just beginning to understand what the incremental drivers were in the\nmost recent quarter like the 2% under discussion. But any thoughts on how tenants are viewing\nthe office portfolio at the moment?',
#  '\nYeah. Sure, Caleb. Thanks for the question. Really the difference between March and June\ncomes to that QUU expiry (00:29:31) and vacation that Dion mentioned.',
#  "\nSo at 7,500 square meters, in Fortitude Valley, where they're located, and moved up, and we're\njust progressively leasing that up. But that's really the difference between the two. And the start\nof the leasing portfolio, I mean, we did more leasing in the second half than we did in the first\nhalf across our office portfolio. So that was pleasing to see sort of 10,000 square meters in the\nfirst half versus 19,000 in the second half. As I mentioned on the call, we had some really strong\nresults, and good tenant inquiry from the government, so backfilling 8,000 square meters in",
#  "\nSkyring Terrace was a terrific effort, particularly given that that had unexpectedly become\nvacant. And I think it just shows the high quality of the assets that we own when you can have\nlimited downtime for that property space. Clearly we're trying to execute a similar strategy with 5",
#  "\nMurray Rose, and that property as I mentioned is getting some good attention, but we need to\nexecute on that. So that's the real focus (00:30:31).",
#  "\nRight. And maybe just if you had any sort of broader thoughts or statements then in terms of\nhow you're thinking about health of tenants across the portfolio, that the WALE is clearly quite\nhelpful until potentially some tenants go into administration, et cetera, as we saw in FY 2023.\n(00:30:56) government should be fine but just in terms of the other corporate across\ngovernment portfolio?",
#  "\nYeah. We have a very strong portfolio of tenant covenants really that there was a bit of an\nexception where we had a tenant go into administration. We monitor our lease on a weekly\nbasis on the de minimis side, we're not seeing any signs across the portfolio of any distressed\ntenants. We've got 95% of the income being derived from non-SME tenants, and like we saw\nduring COVID period, we really have very limited, rent related questions (00:31:36). So, our\nportfolio was in very good shape (00:31:40).",
#  "\nOkay. Great. Thank you very much. That's really helpful. And congratulations again, Tim.",
#  '\nThank you, Caleb.',
#  '\nThank you. Your next question comes from Solomon Zhang at JPMorgan. Please go ahead.',
#  "\nGood morning, Tim and team. First question for me is just on gearing. So I understand you're\nwell within covenant limits, but 37% is I guess, a bit high versus peers. And in the context of a\ndevaluation cycle, just curious, how comfortable are you with current gearing and have you\nbeen considering chopping assets or punching out (00:32:16)?",
#  "\nThanks Solomon, Dion here again. Look, currently your question first off, we're very comfortable\nwhere the gearing currently sits. We've got a range of 35% to 45% we're at the bottom of that\nrange. We're below the bottom of the range at the start (00:32:32), which has now been going\nfor a year. And as you mentioned, we've got plenty of headroom to our covenants. So we're\nvery, very comfortable and we wouldn't be selling assets just to reduce gearing.\n(00:32:43) no assets on the market or in the process.",
#  "\nWe do have two small industrial assets on the market right now, but that's really just normal\nportfolio maintenance.",
#  '\nYep. Got you. Next question is just on the office portfolio, is it a fair comment? I mean, lots of\nyour office portfolio, I guess, is characterized by large (00:33:00). Is this proving to be a bit more\nchallenging to lease up given smaller (00:33:08) are more active in leasing markets right now?',
#  "\nThat's not what we're really saying. We've done a number of (00:33:15) tenants over the last 12\nmonths. We've also done a number of multi-floor tenanted spaces. We've never been adverse\nto chopping close up where we see it's necessary and we're going to drive better leasing\noutcomes. But due to the nature of the asset, the A-grade, high quality, high green credential\ncomponents of those assets they still tend to attract the larger requirements.",
#  '\nYeah. Got you. Maybe another one for you Michael. Just on the re-leasing spreads in industrial,\nwhat are you seeing in your recent leasing and where would you mark to market your rents?',
#  "\nYeah. So I've mentioned on the call that we saw an effective basis sort of circa 30% uplift on the\neffective rents across the industrial portfolio. On the mark-to-market against the value is rents at\n30 June, I think about 8% under, but that's really (00:34:09) on where the rents sit, and\nobviously the market's been moving quite quickly into June.",
#  '\nYeah.',
#  "\nSo, it's a bit Ã¢â‚¬â€œ on a valuation basis (00:34:20).",
#  '\nThank you. Appreciate it.',
#  '\nThank you. Your next question comes from Ben Bradshaw at Barrenjoey. Please go ahead.',
#  '\nTim, congratulations on a very successful tenure as CEO, and all the best for the future.',
#  '\nThank you.',
#  '\nFirst question, just on logistics, I was wondering if you could just describe liquidity at the\nmoment in the current environment as to how it relates to the markets in which you operate for\nthe type of assets in which you own. What sort of buyer demand are you seeing, and is there a\nbid/ask spread?',
#  "\nSo, a good question, Ben. So we obviously work across all the three principal markets and\nthrough the funds management business in the retail sector. So all of those (00:35:20) sectors,\nand this is my observation, that the retail property market is quite liquid with a large format retail,\nwe're seeing neighborhood shopping centers, and a bit more recently we're seeing (00:35:38) in\nregional shopping centers. So they are trading. Industrial, I think a lot of rentals have held off to\ncapture the rental growth coming through. So they're probably a bit more reluctant, but we\nobviously have the AUD 560 million sale of the Korean pension fund to AustralianSuper and\n(00:36:08) managed portfolio. So that's a significant transaction in the market, and shows that\nthere are large institutional investors for large logistics portfolios.",
#  '\nAnd then probably on the smaller side of logistics assets are still trading, still being marketed.',
#  "\nSo it's not as liquid as it was a couple of years ago, but nevertheless, fairly liquid. I think the\noffice sector, as you've probably witnessed, there's probably a larger bid/ask spread, and the\nvolume of assets has come back significantly. And so I would say the liquidity in the office\nsector is probably less strong.",
#  '\nTerrific, Tim. Thanks once again. And congratulations on your time at Growthpoint.',
#  '\nThank you.',
#  '\nThank you. Your next question comes from Howard Penney at Citi. Please go ahead.',
#  "\nThanks, guys, for the presentation. Just one or two additional questions. The first one on the\nfunds management business. What's the outlook to grow the assets under management there\nand attracting additional funds there?",
#  "\nThink you, Howard. It's Tim here. We're confident about it. Obviously, there is less as we just\ncommented. There has been less liquidity in the market. We certainly are looking across sectors\nfor investment opportunities for the investors that we cater for. So our experience, if you find a\ngood deal, the investors will be there. So the high net worth investors and also key cornerstone\ninvestors are also keen to invest again for the right opportunities. I think it's important to note\nthat Australia on a global context is still seen as very attractive. We have a growing population.",
#  "\nWe have a relatively strong economy, and it's well regulated. And any correction in the market\nfor any type of asset is really being seen as an opportunity in the cycle for offshore investors. So\nover the medium term, we are confident about the prospects for the funds management\nbusiness.",
#  '\nGreat. Thank you very much. And I see in the slide pack you mentioned on the vacant space at\n5 Murray Rose and also some advanced negotiations of 2% of the total space. Do you have any\nadditional info on that or timing that you could share?',
#  "\nHoward, it's Michael here. We can't right now, they're sort of progressing at various stages. And",
#  "\nI expect that there'll be a further update obviously at our quarterly announcement, but until then,\nwe can't really disclose anything further.",
#  '\nUnderstood. And just a final question from me. You mentioned that bid/ask spread on office\ntransactions is still wide. But given where cap rates have shifted in this results season on the\noffice side, how far do you think those expectations are from these levels?',
#  "\nI think I think you'll see more liquidity into the market in this next half, clearly the cap rates have\nmoved up in line with some of the transactions that have happened. So I would anticipate the\nbid/ask spread will be narrower this time around.",
#  '\nGreat. Thanks a lot. And well done, Tim. Thank you for the service.',
#  '\nThank you, Howard.',
#  '\nThank you. Your next question comes from Edward Day at Moelis Australia. Please go ahead.',
#  '\nGood morning, Tim and team. And Tim congratulations on your tenure at Growthpoint. Just a\ncouple for me. Just trying to understand your guidance range. Clearly, (00:40:30) 5 Murray',
#  '\nRose is a bit of a swing factor, but wondering what your assumptions are around the\ncontribution from the Fortius business?',
#  "\nYeah. Thanks. I'll take that one. Look, the contribution from the funds management arm is still\nrelatively minor as it is, we need to grow the funds so it start to increase its contribution to our\nresults. So not a big swing factor. Clearly, interest rates, we do have an average that we put into\nour assumptions. But, if you go back two months, that number would have been quite a bit\ndifferent to what it is today. So although it looks a lot more stable today, it is still quite volatile.",
#  "\nSo I think you'll see guidance ranges reasonably wide on that basis alone.",
#  "\nThanks, Dion. And just one more on the funds management business just in terms of\nrelationships with your capital partners, there's obviously been a press around redemption\npressure. Are you seeing any of that coming through that the funds management business?",
#  "\nThanks, Ed. Well, the funds management business obviously has been impacted by higher\ninterest rates, which is across the industry and we have fixed term funds as well. So we're in the\nprocess of paying particular attention to each fund and what the appropriate strategies might be\nto renegotiate covenants and might be to sell the property at their term and realize the funds,\nand then attractive IRR for investors or might be extending the term of the fund for the benefit of\nthe investors. So there's a range of strategies, but no doubt the market circumstances of a\n(00:42:30) fund is, that which is being experienced by the other fund managers as well.",
#  '\nGreat. Thank you.',
#  '\nThank you. Your next question comes from Alex Prineas at Morningstar. Please go ahead.',
#  '\nThank you, and thanks for the presentation. Are you able to say what interest cover ratio is\nimplied by your FY 2024 guidance?',
#  "\nWe're not providing forecast ICRs. Not really in the business of doing that. I think the important\nthing is, when you look at the flexibility or the amount of headroom that we do give in our\npresentation to ICR, (00:43:22) over 50% before we reach that covenant, which I think is highly\nunlikely. So we're not concerned about covenants. We do have a lower covenants and most of\nthem at (00:43:33) 1.6 times, and yeah we're over 3 times as we enter the year, but no, we\nwon't provide a forecast.",
#  "\nOkay. No problem. And just a second one on Ã¢â‚¬â€œ so there's a decent well, pretty low expiries\nthe next couple of years, but FY 2026 it looks like there's a bit of a step up in lease expiries.",
#  '\nJust wondering, it maybe too early, but can you comment at all on how entrenched those\ntenants may be or are they more likely to be in the market for space at that time?',
#  "\nYeah. So two of the key tenants we're looking at there are Woolworths and Linfox. And Linfox,\nfor example, occupy three of our logistics properties at Erskine Park, which is probably the\nhottest logistics market in the country right now. And suffice to say that, that valuation base is\nconsidered to be (00:44:32) on the market rent right now. So I would anticipate that if the market\nconditions prevail in the logistics sector, they'll be very sticky to that location. And if they're not,\nthen we'll have sound reasoning to think that we'll find other tenants in a quick action.",
#  "\nAnd Woolworths is the other large logistics provider in our experience, given that we've had",
#  '\nWoolworths as a major tenant across our portfolio for the last 15 years. It generally takes',
#  "\nWoolworths approximately four to five years to move from one of their major logistics hubs and\nthis is the key distribution center for Western Australia. So again, we would anticipate that\nthere's a high likelihood of renewal and extension there.",
#  '\nGreat. Very interesting. Thanks for that.',
#  '\nThank you. That does conclude our question-and-answer session and our conference for today.',
#  '\nThank you all for participating. You may now disconnect your lines.']

# %% [markdown]
# ## 1.3 - Contar el número de tokens por párrafo
#
# Nuestro objetivo es pasar bloques de texto al LLM para que identifique entidades. Sin embargo, dentro del texto que vamos a pasar al LLM en forma de prompt va a haber información sobre como queremos que se extraigan. Es por ello que tenemos que medir bien los tamaño para que encajen dentro de la ventana de contexto.
#
# Si ajustamos bien el texto, podemos reducir el número de llamadas que hacemos al modelo, y por tanto reducir la latencia de nuestro sistema.
#
# Además saber cuantos tokens hay en cada párrafo nos permite saber cuanto cuesta (aproximadamente) cada llamada al modelo ya que en casos como el de GPT-3, el coste de las llamadas depende del número de tokens utilizados.
#
# Podemos saber cual es el encoding de un modelo llamando al metodo `tiktoken.encoding_for_model()`:

# %%
from tiktoken import encoding_for_model
from pandas import DataFrame

def count_tokens (encoding, text):
    return len(encoding.encode(text))

encoding = encoding_for_model(model) #gpt-3.5-turbo-instruct

#Count tokens for each paragraph and store the results in a list of dictionaries
token_counts = []
for p in cleaned_paragraphs:
    num_tokens = count_tokens(encoding, p)
    token_counts.append({'Paragraph': p, 'Token Count': num_tokens})

#Create a DataFrame from the list of token counts
df = DataFrame(token_counts)
print(f'Nº total de tokens en el archivo: {df["Token Count"].sum()}')

df
# Out:
# Nº total de tokens en el archivo: 8301
#                                              Paragraph  Token Count
# 0    \nGrowthpoint Properties Australia: Q4 2023 Ea...           15
# 1    \nThank you for standing by and welcome to the...           18
# 2    \nResults. All participants are in a listen-on...           26
# 3    \nI would now like to hand the conference over...           26
# 4    \nGood morning, and welcome to Growthpoint Pro...           40
# ..                                                 ...          ...
# 135  \nWoolworths as a major tenant across our port...           22
# 136  \nWoolworths approximately four to five years ...           50
# 137        \nGreat. Very interesting. Thanks for that.           10
# 138  \nThank you. That does conclude our question-a...           18
# 139  \nThank you all for participating. You may now...           14
#
# [140 rows x 2 columns]

# %% [markdown]
# # 2 - Extraer entidades y relaciones
#
# En esta tarea, combinamos las tareas NLP de "entity-extraction" y "relation-extraction" mediante un enfoque generativo.
#
# * `Entity-extraction` (extracción de entidades). Se refiere a la identificación y clasificación de entidades mencionadas en el texto, como nombres de personas, lugares , organizaciones, etc.
# * `Relation-extraction` (extracción de relaciones). Implica identificar y clasificar las relaciones semánticas entre entidades previamente extraidas. Por ejemplo, en una oración como "Bill gates es fundador de Microsoft", identificariamos la relación "fundador" entre las entidades "Bill Gates" y "Microsoft". Otras posibles relaciones que se pueden extraer indirectamente son: "Bill Gates es emprendedor", "Bill Gates es empresario", etc.
#
#
# Para lograrlo, utilizaremos GPT-3 con Langchain, empleando una LLMChain. Como ya hemos visto, la LLMChain se compone de un PromptTemplate, un modelo y opcionalmente un formateador del output.
#
# Nuestro objetivo implica identificar los siguientes elementos:
#
# * Entidades, como `individuos y empresas`.
# * Atributos pertinentes asociados con estas entidades, como `roles o relaciones`.
#
#
# Nos centraremos principalmente en tres tipos de relaciones que existen entre entidades:
#
# 1. `<is_a>`: Esta relación es útil para definir la naturaleza de empresas, lugares o activos.
# 2. `<works_at>`: Esta relación indica el lugar de empleo de una persona.
# 3. `<has_position>`: Esta relación especifica el rol o posición que ocupa una persona dentro de la empresa con la que está asociada.
#
#
# `Nota`: Si bien este enfoque podria ampliarse a otras relaciones más complejas, hemos optado por centrarnos en estas tres por claridad y con fines de demonstración.

# %%
entity_relationships_task = 'entity_relationships'

# %% [markdown]
# ## 2.1 - Preparar el prompt
#
# ### Prompt base
#
# Hemos dividio el prompt en 3 partes, cada una de ellas se encuentra en un archivo de texto:
#
# * `base_template.txt`. Tiene el texto base que da contexto al modelo sobre lo que le vamos a pedir. Basicamente le indicamos que queremos hacer una tarea de extracción, donde las relaciones que encuentre el modelo en el texto deben ser indicadas en el formato ENTITY_1 <RELATIONSHIP> ENTITY_2.
# * `pcpa.txt`. Indica el tipo de relaciones que nos interesan, y provee al modelo de explicaciones sobre cada una de ellas, para darle contexto.
# * `pcpa_microsoft`. Contiene un ejemplo hecho a mano (one-shot learning) donde a partir de un texto, le indicamos que relaciones deberia extraer del mismo.
#
# La idea de este prompt es explicar al LLM lo mejor posible la tarea para que pueda extraer correctamente entidades en el formato especificado. Como no hemos hecho ningún tipo de fine-tuning, hay que hacer algo de "prompt engineering".

# %%
from pathlib import Path

#Ruta al archivo base de plantilla para tareas de extracción de entidades
base_template_path = Path(f'{getcwd()}/prompts/templates/{entity_relationships_task}/base_template.txt')
relationships_template_path = Path(f'{getcwd()}/prompts/templates/{entity_relationships_task}/pcpa.txt')
example_template_path = Path(f'{getcwd()}/prompts/examples/{entity_relationships_task}/pcpa_microsoft.txt')

# Leer el contenido de cada plantilla desde el archivo
with open (base_template_path, 'r') as pf:
    base_template = pf.read()

with open (relationships_template_path, 'r') as pf:
    relationships_template = pf.read()

with open (example_template_path, 'r') as pf:
    example_prompt = pf.read()

#Combinar el texto del ej con el template del tipo de relaciones que nos interesan
prompt_text = relationships_template.format(example=example_prompt)

#Combinar el texto de la plantilla base ocn el prompt anterior
prompt_text = base_template.format(prompt=prompt_text)

# Contar el nº de tokens en el txt del prompt
n_prompt_tokens = count_tokens(encoding, prompt_text)
print(n_prompt_tokens)
# Out:
# 208

# %%
print(prompt_text)
# Out:
# You are an expert in finance and financial news. You are great at extracting key business developments from earnings calls, news and financial documents.
#
# When you are asked about the extraction of business developments from a text, you provide a list with the following format, where you rate them as positive and negative by giving them a score between -10 (very negative) and 10 (very positive):
#
# <Business development summary> | <Score> | <Reason for score>
#
# Here is what you should include in each list element:
#
# * Business development summary. Write a headline explaining key aspects of the business development
# * Score. Just write a number between -10 and 10 to indicate the positivity or negativity of the development
# * Reason for score. Explanation about why the development is either positive or negative. Please include metrics and relevant information to support your reasoning.
#
# Important: You should return your response that way. Do not write anything else outside of that. Do not include aything else!
#
# Now, please extract bussiness developments from the following text:

# %% [markdown]
# ### Preparar chunks de texto a analizar
# Con el texto anterior ya tenemos el contexto necesario para el LLM. Ahora lo que tenemos que hacer es preparar los chunks de texto de entrada para el modelo.
#
# En este sentido, es muy importante adecuar de forma correcta el tamaño de los chunks, ya que si nos pasamos de tamaño el modelo nos dará un error (o no generará todo lo necesario). Hay 4 variables a considerar cuando decidimos el tamaño de los chunks:
#
# El contexto máximo del modelo (en numero de tokens). En el caso de GPT-3 es 4096. Esto incluye tanto entrada como generación.
# El número máximo de tokens que damos de margen al modelo para generar.
# Además de estos dos, hay que tener que el prompt base ya tiene un numero de tokens (899) y que tiktoken no es deterministico (lo he observado empíricamente pero no he investigado la razón). Por ello el número máximo de tokens del chunk se puede estimar con la siguiente fórmula:
#
# `max_tokens_per_chunk = MODEL_CONTEXT_LENGTH - MAX_GENERATION_LENGTH - EXTRA_TOKENS_FOR_TOKENIZATION_VARIABILITY - n_prompt_tokens`
#
# `max_tokens_per_chunk = 4097 - 1000 - 50 - 899`
#
# `max_tokens_per_chunk = 2148`
#
# Cómo máximo vamos a permitir chunks de 2147 tokens. Además, como nuestro objetivo es identificar entidades, vamos a evitar cortar párrafos por la mitad ya que podria afectar a las entidades o las relaciones.

# %%
MODEL_CONTEXT_LENGTH = 4097
MAX_GENERATION_LENGTH = 1000
EXTRA_TOKENS_FOR_TOKENIZATION_VARIABILITY = 50 #not sure why, but I have run the same process multiple times and I have seen different tokenizations, need to double check this
llm.max_tokens = MAX_GENERATION_LENGTH

# Número máximo de tokens por chunk
max_tokens_per_chunk = MODEL_CONTEXT_LENGTH - MAX_GENERATION_LENGTH - EXTRA_TOKENS_FOR_TOKENIZATION_VARIABILITY - n_prompt_tokens

print(f"Nº máx de tokens por chunk: {max_tokens_per_chunk}")

def generate_chunks(df, max_tokens_per_chunks):
    #Inicializar variables
    chunks = []
    current_chunk = []
    current_token_count = 0

    #Iterar a través de las filas del DF, que son párrafos del texto
    for idx, row in df.iterrows():
        paragraph = row['Paragraph']
        num_tokens = row['Token Count']

        # Si agregar el párrafo actual al fragmento actual no excede el límite
        if current_token_count + num_tokens <= max_tokens_per_chunks:
            current_chunk.append(paragraph)
            current_token_count += num_tokens
        else:
            #Agregar el párrafo actual a la lista de chunks
            if current_chunk:
                chunks.append("".join(current_chunk))
            #Comenzar un nuevo chunk con el párrafo actual
            current_chunk = [paragraph]
            current_token_count = num_tokens
    if current_chunk:
        chunks.append("".join(current_chunk))

    return chunks
# Out:
# Nº máx de tokens por chunk: 2839

# %%
chunks = generate_chunks(df, max_tokens_per_chunk)

# %%
total_token_count = 0

for i in range(0, len(chunks)):
    token_counts = count_tokens(encoding, chunks[i])
    print(f'{i}: {token_counts}')
    total_token_count += token_counts

print(f'Total: {total_token_count}')
# Out:
# 0: 2771
# 1: 2732
# 2: 2686
# Total: 8189

# %% [markdown]
# ## 2.2 - Correr el prompt por el LLM

# %%
from time import time

from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.callbacks import get_openai_callback

def llm_run(chain, query):
    start_time = time()

    with get_openai_callback() as cb:
        result = chain.run(query)
        print(f'Spent a total of {cb.total_tokens} tokens')

    end_time = time()
    execution_time = end_time - start_time
    print(f'Time taken: {round(execution_time, 2)} seconds')

    return result

#Crear la plantilla del prompt
prompt = PromptTemplate(
    input_variables=['input_text'],
    template=prompt_text + '\n{input_text}',
)

# Crear la cadena LLM simple
llm_chain = LLMChain(llm=llm, prompt=prompt)

er_outputs = []
for i in range(len(chunks)):
    print(f"Chunk {i}")
    output = llm_run(llm_chain, chunks[i])
    er_outputs.append(output)
# Out:
# Chunk 0
# Spent a total of 3978 tokens
# Time taken: 13.65 seconds
# Chunk 1
# Spent a total of 3939 tokens
# Time taken: 13.5 seconds
# Chunk 2
# Spent a total of 3336 tokens
# Time taken: 6.23 seconds

# %%
er_outputs
# Out:
# ["\nOlympic Park, and a AUD 1.2 million lease break fee received in relation to 100 Skyring Terrace\nin Brisbane. Excluding these one-offs, NPI would have been down 1.3% on last year.\nThe group's interest cover ratio remains strong at 4.8 times, and our gearing remains at the low\nend of our target range at 29.3%. The group's weighted average debt maturity is 4.1 years, and\nwe have no debt maturing until December 2024. The group's weighted average cost of debt\nincreased to 2.9% from 2.6% last year, mainly due to the increase in market interest rates.\nMoving to slide 21, and the group's capital management. The group's balance sheet remains\nstrong, and we have a range of options available to us to fund our growth initiatives. We\ncompleted the AUD 100 million securities buyback program in May 2023, which was accretive to\nFFO per security. We have a number of unencumbered assets, which provide us with significant\nfunding flexibility. We have a strong relationship with our banks, and we have a range of debt\nfacilities available to us, which are currently undrawn.\nOn slide 22, we highlight the group's debt metrics. The group's weighted average debt maturity\nremains at 4.1 years, and we have no debt maturing until December 2024. The group's weighted\naverage cost of debt increased to 2.9% from 2.6% last year, mainly due to the increase in market\ninterest rates. The group's gearing remains at the low end of our target range at 29.3%, and our\ninterest cover ratio remains strong at 4.8 times.\nOn slide 23, we highlight the group's debt facilities. The group has a range of debt facilities\navailable to us, which are currently undrawn. We have a strong relationship with our banks, and\nwe have a range of debt facilities available to us, which are currently undrawn. We have a strong\nrelationship with our banks, and we have a range of debt facilities available to us, which are\ncurrently undrawn. We have a strong relationship with our banks, and we have a range of debt\nfacilities available to us, which are currently undrawn. We have a strong relationship with our\nbanks, and we have a range of debt facilities available to us, which are currently undrawn. We\nhave a strong relationship with our banks, and we have a range of debt facilities available to us,\nwhich are currently undrawn. We have a strong relationship with our banks, and we have a range\nof debt facilities available to us, which are currently undrawn. We have a strong relationship with\nour banks, and we have a range of debt facilities available to us, which are currently undrawn.\nWe have a strong relationship with our banks, and we have a range of debt facilities available to\nus, which are currently undrawn.\n\nGrowthpoint Properties Australia: Q4 2023 Earnings Call\n1. Strong leasing performance and occupancy | 8 | Growthpoint has successfully leased over 156,000 square meters, equivalent to 11.2% of income, resulting in a 93% occupancy rate across the portfolio. This demonstrates the company's ability to attract and retain tenants, which is a positive sign for future income and growth.\n2. Successful integration of Fortius Funds Management platform | 9 | Despite challenging market conditions, Growthpoint has successfully integrated the Fortius Funds Management platform, which was acquired in September 2022. This acquisition has added value to the company and has the potential for future growth.\n3. Lower FFO but above initial guidance | -5 | Due to higher interest rates, FFO was lower than the previous year. However, it was still above initial guidance provided at the financial year 2022 results, which shows the company's ability to manage and mitigate the impact of external factors.\n4. Decline in property portfolio value | -7 | The group's property portfolio value decreased by 6.5% on a like-for-like basis over 12 months due to higher interest rates and consequential impact on capitalization and discount rates. This was a primary driver of the lower NTA.\n ...
#  " And then we've got a couple of other\nproperties that we're working on, but they're not as significant as those two.\nThank you. And just one final one from me, if I may. Just around the industrial portfolio, and\nmaybe a question for Michael as well. But just trying to understand the 2.5% NPI growth in the\nsecond half, and how that was driven. I think you mentioned some rent reviews, but just trying to\nunderstand the drivers of that, and how sustainable that is going forward.\nYeah. Sure. So the 2.5% was really driven by the rent reviews. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and that was really the driver of that. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and that was really the driver of that. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and that was really the driver of that. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and that was really the driver of that. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and that was really the driver of that. So we had a couple of rent\nreviews that were completed in the second half, and that was really the driver of that. So we had\na couple of rent reviews that were completed in the second half, and that was really the driver of\nthat. So we had a couple of rent reviews that were completed in the second half, and that was\nreally the driver of that. So we had a couple of rent reviews that were completed in the second\nhalf, and that was really the driver of that. So we had a couple of rent reviews that were\ncompleted in the second half, and ...
#  '\n\n1. Strong portfolio of tenant covenants | 8 | The company has a strong portfolio of tenants with only one exception of a tenant going into administration. They monitor their leases regularly and have a high percentage of income from non-SME tenants, which is a positive sign for the health of their tenants.\n\n2. Limited rent-related questions during COVID period | 9 | The company saw limited rent-related questions during the COVID period, indicating that their portfolio was in good shape and their tenants were able to pay their rent.\n\n3. Comfortable with current gearing | 7 | The company is currently at the bottom of their target gearing range and has plenty of headroom to their covenants, making them comfortable with their current gearing level.\n\n4. Two small industrial assets on the market | 5 | The company has two small industrial assets on the market for sale, which is a normal part of their portfolio maintenance.\n\n5. Liquidity in retail property market | 6 | The retail property market is seen as quite liquid, with large format retail, neighborhood shopping centers, and regional shopping centers all trading.\n\n6. Bid/ask spread in office transactions | 4 | The bid/ask spread in office transactions is still wide, but the company expects it to be narrower in the next half.\n\n7. Contribution from funds management business | 3 | The contribution from the funds management arm is still relatively minor, but the company is confident about its prospects for growth in the medium term.\n\n8. Impact of higher interest rates on funds management business | -6 | The funds management business has been impacted by higher interest rates, which has led to the need for renegotiating covenants and considering strategies such as selling properties or extending the term of funds.\n\n9. Low expiries in the next couple of years | 7 | The company has a low number of lease expiries in the next couple of years, indicating stability in their portfolio.\n\n10. Potential for renewal and extension of leases with key tenants | 8 | The company has a high likelihood of renewing and extending leases with key tenants such as Woolworths and Linfox, based on their past experiences and market conditions.']

# %% [markdown]
# Si bien el modelo nos devuelve tripletas de `"Entidad_1" <relacion> "Entidad_2"`, lo hace en forma de bloque de texto. Para poder utilizar dichas relaciones y almacenarlas por ejemplo en una base de datos en grafo como Node4J, tenemos que primero formatearlas correctamente...

# %%
print(er_outputs[0])
# Out:
# Olympic Park, and a AUD 1.2 million lease break fee received in relation to 100 Skyring Terrace
# in Brisbane. Excluding these one-offs, NPI would have been down 1.3% on last year.
# The group's interest cover ratio remains strong at 4.8 times, and our gearing remains at the low
# end of our target range at 29.3%. The group's weighted average debt maturity is 4.1 years, and
# we have no debt maturing until December 2024. The group's weighted average cost of debt
# increased to 2.9% from 2.6% last year, mainly due to the increase in market interest rates.
# Moving to slide 21, and the group's capital management. The group's balance sheet remains
# strong, and we have a range of options available to us to fund our growth initiatives. We
# completed the AUD 100 million securities buyback program in May 2023, which was accretive to
# FFO per security. We have a number of unencumbered assets, which provide us with significant
# funding flexibility. We have a strong relationship with our banks, and we have a range of debt
# facilities available to us, which are currently undrawn.
# On slide 22, we highlight the group's debt metrics. The group's weighted average debt maturity
# remains at 4.1 years, and we have no debt maturing until December 2024. The group's weighted
# average cost of debt increased to 2.9% from 2.6% last year, mainly due to the increase in market
# interest rates. The group's gearing remains at the low end of our target range at 29.3%, and our
# interest cover ratio remains strong at 4.8 times.
# On slide 23, we highlight the group's debt facilities. The group has a range of debt facilities
# available to us, which are currently undrawn. We have a strong relationship with our banks, and
# we have a range of debt facilities available to us, which are currently undrawn. We have a strong
# relationship with our banks, and we have a range of debt facilities available to us, which are
# currently undrawn. We have a strong relationship with our banks, and we have a range of debt
# facilities available to us, which are currently undrawn. We have a strong relationship with our
# banks, and we have a range of debt facilities available to us, which are currently undrawn. We
# have a strong relationship with our banks, and we have a range of debt facilities available to us,
# which are currently undrawn. We have a strong relationship with our banks, and we have a range
# of debt facilities available to us, which are currently undrawn. We have a strong relationship with
# our banks, and we have a range of debt facilities available to us, which are currently undrawn.
# We have a strong relationship with our banks, and we have a range of debt facilities available to
# us, which are currently undrawn.
#
# Growthpoint Properties Australia: Q4 2023 Earnings Call
# 1. Strong leasing performance and occupancy | 8 | Growthpoint has successfully leased over 156,000 square meters, equivalent to 11.2% of income, resulting in a 93% occupancy rate across the portfolio. This demonstrates the company's ability to attract and retain tenants, which is a positive sign for future income and growth.
# 2. Successful integration of Fortius Funds Management platform | 9 | Despite challenging market conditions, Growthpoint has successfully integrated the Fortius Funds Management platform, which was acquired in September 2022. This acquisition has added value to the company and has the potential for future growth.
# 3. Lower FFO but above initial guidance | -5 | Due to higher interest rates, FFO was lower than the previous year. However, it was still above initial guidance provided at the financial year 2022 results, which shows the company's ability to manage and mitigate the impact of external factors.
# 4. Decline in property portfolio value | -7 | The group's property portfolio value decreased by 6.5% on a like-for-like basis over 12 months due to higher interest rates and consequential impact on capitalization and discount rates. This was a primary driver of the lower NTA.
# 5. Strong leasing activity in metro and fringe CBD office markets | 8 | According to JLL data, the metro and fringe CBD office markets have grown more strongly than CBDs, reflecting tenant demand. Growthpoint's portfolio is well-positioned in these markets, with high-quality assets and close proximity to key transport modes.
# 6. Positive leasing spreads in industrial property sector | 9 | The industrial property sector has seen positive momentum due to a shortage of modern warehouse space and growth in

# %% [markdown]
# ## 2.3 - Formatear la salida
#
# Dividimos aquellas lineas de texto que se encuentran en formato `"Entidad_1" <relacion> "Entidad_2"` y las almacenamos en un DataFrame de Pandas. Por supuesto, aquellas que no cumplen con las reglas son ignoradas.

# %%
from pandas import concat as pdconcat, Series as pdSeries
from re import findall as refindall, match as rematch


def split_relationship_text(text):
    #Dividir el texto basándose en "<" y ">" para separar la parte de la relación
    #match = rematch(r'(.+?)\s*\|\s*(\d+)\s*\|\s*(.+)', text)
    match = rematch(r'(.+?)\s*\|\s*(\d+)\s*\|\s*(.+)', text)

    print(match)
    

    if match:
        #Extraer entidades y relación
        entity1 = match.group(1).strip()
        relationship = match.group(2).strip()
        entity2 = match.group(3).strip()

        return entity1, relationship, entity2
    
    else:
        #Manejar de manera elegante la entrada no válida
        print(f'Formato no válido para: {text}')
        return None, None, None
    
er_outputs_dfs = []

#Crear DataFrames para cada salida en er_outputs
for out in er_outputs:
    er_outputs_dfs.append(DataFrame({"Triplet": out.split('\n')}))

#Concatenar los DF
er_output_df = pdconcat(er_outputs_dfs)

#Eliminar filas vacías y duplicados basados en la columna "Triplet"
er_output_df = er_output_df[~er_output_df["Triplet"].str.startswith("Resultado:") & (er_output_df["Triplet"] != "")]

#er_output_df = er_output_df[er_output_df["Triplet"] != ""]
er_output_df = er_output_df.drop_duplicates(["Triplet"]).reset_index(drop=True).copy()

#Aplicar la función al DF y crear nuevas columnas
er_output_df[['Entidad 1', 'Relación', 'Entidad 2']] = er_output_df['Triplet'].apply(
    lambda x: pdSeries(split_relationship_text(x))
)
# Out:
# None
# Formato no válido para: Olympic Park, and a AUD 1.2 million lease break fee received in relation to 100 Skyring Terrace
# None
# Formato no válido para: in Brisbane. Excluding these one-offs, NPI would have been down 1.3% on last year.
# None
# Formato no válido para: The group's interest cover ratio remains strong at 4.8 times, and our gearing remains at the low
# None
# Formato no válido para: end of our target range at 29.3%. The group's weighted average debt maturity is 4.1 years, and
# None
# Formato no válido para: we have no debt maturing until December 2024. The group's weighted average cost of debt
# None
# Formato no válido para: increased to 2.9% from 2.6% last year, mainly due to the increase in market interest rates.
# None
# Formato no válido para: Moving to slide 21, and the group's capital management. The group's balance sheet remains
# None
# Formato no válido para: strong, and we have a range of options available to us to fund our growth initiatives. We
# None
# Formato no válido para: completed the AUD 100 million securities buyback program in May 2023, which was accretive to
# None
# Formato no válido para: FFO per security. We have a number of unencumbered assets, which provide us with significant
# None
# Formato no válido para: funding flexibility. We have a strong relationship with our banks, and we have a range of debt
# None
# Formato no válido para: facilities available to us, which are currently undrawn.
# None
# Formato no válido para: On slide 22, we highlight the group's debt metrics. The group's weighted average debt maturity
# None
# Formato no válido para: remains at 4.1 years, and we have no debt maturing until December 2024. The group's weighted
# None
# Formato no válido para: average cost of debt increased to 2.9% from 2.6% last year, mainly due to the increase in market
# None
# Formato no válido para: interest rates. The group's gearing remains at the low end of our target range at 29.3%, and our
# None
# Formato no válido para: interest cover ratio remains strong at 4.8 times.
# None
# Formato no válido para: On slide 23, we highlight the group's debt facilities. The group has a range of debt facilities
# None
# Formato no válido para: available to us, which are currently undrawn. We have a strong relationship with our banks, and
# None
# Formato no válido para: we have a range of debt facilities available to us, which are currently undrawn. We have a strong
# None
# Formato no válido para: relationship with our banks, and we have a range of debt facilities available to us, which are
# None
# Formato no válido para: currently undrawn. We have a strong relationship with our banks, and we have a range of debt
# None
# Formato no válido para: facilities available to us, which are currently undrawn. We have a strong relationship with our
# None
# Formato no válido para: banks, and we have a range of debt facilities available to us, which are currently undrawn. We
# None
# Formato no válido para: have a strong relationship with our banks, and we have a range of debt facilities available to us,
# None
# Formato no válido para: which are currently undrawn. We have a strong relationship with our banks, and we have a range
# None
# Formato no válido para: of debt facilities available to us, which are currently undrawn. We have a strong relationship with
# None
# Formato no válido para: our banks, and we have a range of debt facilities available to us, which are currently undrawn.
# None
# Formato no válido para: We have a strong relationship with our banks, and we have a range of debt facilities available to
# None
# Formato no válido para: us, which are currently undrawn.
# None
# Formato no válido para: Growthpoint Properties Australia: Q4 2023 Earnings Call
# <re.Match object; span=(0, 326), match="1. Strong leasing performance and occupancy | 8 |>
# <re.Match object; span=(0, 313), match='2. Successful integration of Fortius Funds Manage>
# None
# Formato no válido para: 3. Lower FFO but above initial guidance | -5 | Due to higher interest rates, FFO was lower than the previous year. However, it was still above initial guidance provided at the financial year 2022 results, which shows the company's ability to manage and mitigate the impact of external factors.
# None
# Formato no válido para: 4. Decline in property portfolio value | -7 | The group's property portfolio value decreased by 6.5% on a like-for-like basis over 12 months due to higher interest rates and consequential impact on capitalization and discount rates. This was a primary driver of the lower NTA.
# <re.Match object; span=(0, 326), match="5. Strong leasing activity in metro and fringe CB>
# <re.Match object; span=(0, 179), match='6. Positive leasing spreads in industrial propert>
# None
# Formato no válido para:  And then we've got a couple of other
# None
# Formato no válido para: properties that we're working on, but they're not as significant as those two.
# None
# Formato no válido para: Thank you. And just one final one from me, if I may. Just around the industrial portfolio, and
# None
# Formato no válido para: maybe a question for Michael as well. But just trying to understand the 2.5% NPI growth in the
# None
# Formato no válido para: second half, and how that was driven. I think you mentioned some rent reviews, but just trying to
# None
# Formato no válido para: understand the drivers of that, and how sustainable that is going forward.
# None
# Formato no válido para: Yeah. Sure. So the 2.5% was really driven by the rent reviews. So we had a couple of rent
# None
# Formato no válido para: reviews that were completed in the second half, and that was really the driver of that. So we had
# None
# Formato no válido para: a couple of rent reviews that were completed in the second half, and that was really the driver of
# None
# Formato no válido para: that. So we had a couple of rent reviews that were completed in the second half, and that was
# None
# Formato no válido para: really the driver of that. So we had a couple of rent reviews that were completed in the second
# None
# Formato no válido para: half, and that was really the driver of that. So we had a couple of rent reviews that were
# None
# Formato no válido para: completed in the second half, and that was really the driver of that. So we had a couple of rent
# None
# Formato no válido para: really the driver of that. So we had a
# <re.Match object; span=(0, 307), match='1. Strong portfolio of tenant covenants | 8 | The>
# <re.Match object; span=(0, 228), match='2. Limited rent-related questions during COVID pe>
# <re.Match object; span=(0, 215), match='3. Comfortable with current gearing | 7 | The com>
# <re.Match object; span=(0, 173), match='4. Two small industrial assets on the market | 5 >
# <re.Match object; span=(0, 196), match='5. Liquidity in retail property market | 6 | The >
# <re.Match object; span=(0, 163), match='6. Bid/ask spread in office transactions | 4 | Th>
# <re.Match object; span=(0, 206), match='7. Contribution from funds management business | >
# None
# Formato no válido para: 8. Impact of higher interest rates on funds management business | -6 | The funds management business has been impacted by higher interest rates, which has led to the need for renegotiating covenants and considering strategies such as selling properties or extending the term of funds.
# <re.Match object; span=(0, 166), match='9. Low expiries in the next couple of years | 7 |>
# <re.Match object; span=(0, 242), match='10. Potential for renewal and extension of leases>

# %%
er_output_df
# Out:
#                                               Triplet  \
# 0   Olympic Park, and a AUD 1.2 million lease brea...
# 1   in Brisbane. Excluding these one-offs, NPI wou...
# 2   The group's interest cover ratio remains stron...
# 3   end of our target range at 29.3%. The group's ...
# 4   we have no debt maturing until December 2024. ...
# ..                                                ...
# 56  6. Bid/ask spread in office transactions | 4 |...
# 57  7. Contribution from funds management business...
# 58  8. Impact of higher interest rates on funds ma...
# 59  9. Low expiries in the next couple of years | ...
# 60  10. Potential for renewal and extension of lea...
#
#                                             Entidad 1 Relación  \
# 0                                                None     None
# 1                                                None     None
# 2                                                None     None
# 3                                                None     None
# 4                                                None     None
# ..                                                ...      ...
# 56           6. Bid/ask spread in office transactions        4
# 57     7. Contribution from funds management business        3
# 58                                               None     None
# 59        9. Low expiries in the next couple of years        7
# 60  10. Potential for renewal and extension of lea...        8
#
#                                             Entidad 2
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 56  The bid/ask spread in office transactions is s...
# 57  The contribution from the funds management arm...
# 58                                               None
# 59  The company has a low number of lease expiries...
# 60  The company has a high likelihood of renewing ...
#
# [61 rows x 4 columns]

# %% [markdown]
# # 3 - Identificar eventos relevantes
#
# Esta tarea es una combinación de resumen y clasificación:
#
# "Resumimos" el texto extrayendo eventos relevantes
# Clasificamos los eventos como positivos o negativos.
# Para ello, utilizaremos GPT-3 con Langchain, empleando una LLMChain. Como ya hemos visto, la LLMChain se compone de un PromptTemplate, un modelo y opcionalmente un formateador del output.
#
# Nota: También podríamos probar un enfoque diferente donde dividimos el proceso en dos partes y utilizamos SimpleSequentialChain, donde la salida de un paso es la entrada al siguiente. Esto nos permitiría utilizar modelos diferentes para diferentes partes del proceso. Sería el enfoque que habría elegido si tuviera que trabajar con LLMs menos potentes (también más económicos), sobretodo si contase con más dato para entrenarlos.
#
# La primera cadena generaría una lista de eventos.
# La segunda cadena tomaría la lista de eventos como entrada y los clasificaría como positivos o negativos.

# %%
business_developments_task = 'business_developments'

# %% [markdown]
# ## 3.1 - Preparar el prompt

# %% [markdown]
# ### Prompt base
#
# En este caso vamos a trabajar con un template más simple que en la tarea anterior ya que no vamos a proveer de ejemplos (zero-shot learning). En este caso simplemente proveemos de un texto explcativo para el modelo.
#
# `Nota`: Realmente tengo preparado otro con ejemplo, pero haciendo pruebas con el me ha dado peores resultados, por lo que he decido utilizar zero-shot learning mejor que one-shot o few-shot learning

# %%
#Template base para la tarea de identificación de eventos relevantes
base_template_path = Path(f'{getcwd()}\\prompts\\templates\\{business_developments_task}\\base_template.txt')

with open(base_template_path, 'r') as prompt_file:
    base_template = prompt_file.read()

prompt_text = base_template

n_prompt_tokens = count_tokens(encoding, prompt_text)
print(n_prompt_tokens)
# Out:
# 208

# %%
print(prompt_text)
# Out:
# You are an expert in finance and financial news. You are great at extracting key business developments from earnings calls, news and financial documents.
#
# When you are asked about the extraction of business developments from a text, you provide a list with the following format, where you rate them as positive and negative by giving them a score between -10 (very negative) and 10 (very positive):
#
# <Business development summary> | <Score> | <Reason for score>
#
# Here is what you should include in each list element:
#
# * Business development summary. Write a headline explaining key aspects of the business development
# * Score. Just write a number between -10 and 10 to indicate the positivity or negativity of the development
# * Reason for score. Explanation about why the development is either positive or negative. Please include metrics and relevant information to support your reasoning.
#
# Important: You should return your response that way. Do not write anything else outside of that. Do not include aything else!
#
# Now, please extract bussiness developments from the following text:

# %% [markdown]
# # Preparar chunks de texto a analizar
#
# Ya hemos definido previamente la función generate_chunks(). En este caso, solo tenemos que utilizarla correctamente:
#
# max_tokens_per_chunk = MODEL_CONTEXT_LENGTH - MAX_GENERATION_LENGTH - EXTRA_TOKENS_FOR_TOKENIZATION_VARIABILITY - n_prompt_tokens
#
# max_tokens_per_chunk = 4097 - 1000 - 50 - 220
#
# max_tokens_per_chunk = 2827
#
#
# Nota: En este caso me encontré un error algo extraño de OpenAI (Error in OpenAICallbackHandler.on_llm_end callback: TypeError("unsupported operand type(s) for /: 'NoneType' and 'int'")), asi que modifique la longitud de los chunks y funciona...

# %%
max_tokens_per_chunk = 3201 - MAX_GENERATION_LENGTH - EXTRA_TOKENS_FOR_TOKENIZATION_VARIABILITY

chunks = generate_chunks(df, max_tokens_per_chunk)

total_token_count = 0

for i in range(0, len(chunks)):
    token_counts = count_tokens(encoding, chunks[i])
    print(f'{i}: {token_counts}')
    total_token_count += token_counts

print(f'"Total: {total_token_count}')
# Out:
# 0: 2068
# 1: 2004
# 2: 2105
# 3: 2014
# "Total: 8191

# %% [markdown]
# ## 3.2 - Correr el prompt por el LLM

# %%
prompt = PromptTemplate(
    input_variables=['input_text'],
    template=prompt_text + "\n{input_text}"
)

llm_chain = LLMChain(llm=llm, prompt=prompt)

bd_outputs = []
for i in range(len(chunks)):
    print(f"Chunks: {i}")
    output = llm_run(llm_chain, chunks[i])
    bd_outputs.append(output)
# Out:
# Chunks: 0
# Spent a total of 3146 tokens
# Time taken: 11.79 seconds
# Chunks: 1
# Spent a total of 2891 tokens
# Time taken: 8.11 seconds
# Chunks: 2
# Spent a total of 3237 tokens
# Time taken: 11.34 seconds
# Chunks: 3
# Spent a total of 2665 tokens
# Time taken: 6.08 seconds

# %%
bd_outputs
# Out:
# [" We are proud of\nachieving a 92% satisfaction rating, which is a testament to our team's focus on tenant\nengagement.\n\nGrowthpoint Properties Australia: Q4 2023 Earnings Call\n\n1. Growthpoint's leasing performance was strong, with over 156,000 square meters leased equivalent to 11.2% of income, resulting in occupancy of 93% across the portfolio. | Score: 8 | This is a positive development as it shows a high occupancy rate and strong leasing performance, which will lead to sustainable income returns for securityholders.\n\n2. The group's goal remains to provide securityholders with sustainable income returns and capital appreciation over the long-term. | Score: 9 | This is a very positive development as it shows the company's commitment to its investors and its long-term strategy for growth and value creation.\n\n3. In financial year 2023, Growthpoint purchased the GSO building in Dandenong with a 9.4-year WALE and divested 333 Ann Street, Brisbane with a 3.7-year WALE. | Score: 7 | This is a positive development as it shows the company's focus on acquiring high-quality assets and divesting underperforming ones, which will maximize value for securityholders.\n\n4. Capital management remains a sharp focus given the high interest rate environment. | Score: 8 | This is a positive development as it shows the company's proactive approach to managing its capital in a challenging market environment.\n\n5. The group's property portfolio value decreased by 6.5% on a like-for-like basis over 12 months due to higher interest rates and consequential impact on capitalization and discount rates. | Score: -6 | This is a negative development as it shows a decline in the company's property portfolio value, which will have a negative impact on its net tangible assets (NTA).\n\n6. Despite challenging market conditions, distributions declared for the period were up 2.9%. | Score: 7 | This is a positive development as it shows the company's ability to maintain and even increase distributions to its investors despite challenging market conditions.\n\n7. The positive momentum in the industrial markets continued in financial year 2023 due to a shortage of modern warehouse space across all markets, underpinned by growth in e-commerce and demand for supply chain infrastructure. | Score: 9 | This is a very positive development as it shows a strong demand for the company's industrial properties, which will lead to higher rental growth and occupancy rates.\n\n8. The acquisition of Fortius Funds Management, a property fund manager with a 30-year plus track record of delivering strong returns to its investors, was completed in September 2022. | Score: 9 | This is a very positive development as it shows the company's expansion into the funds management business, which will provide long-term growth opportunities and strong returns for investors.\n\n9. The group's office portfolio is reduced by 9.4% on a like-for-like basis over the year, while the industrial portfolio valuations only have witnessed a slight decline. | Score: -5 | This is a negative development as it shows a decline in the company's office portfolio value, which will have a negative impact on its NTA.\n\n10. Tenant engagement is a major focus for Growthpoint, and this has been reflected by achieving industry leading tenant satisfaction results in the independent annual tenant survey. | Score: 10 | This is a very positive development as it shows the company's commitment to tenant satisfaction, which will lead to higher retention rates and a positive reputation in the market.\n\n11. The company's high quality, energy efficient buildings are attractive for government tenants, and the WALE of its government office tenants is 10.3 years. | Score: 9 | This is a very positive development as it shows the company's strong tenant base and long-term lease agreements with government tenants, which will provide stability and consistent income for securityholders.\n\n12. Growthpoint achieved a 92% sati ...
#  "\n\nLeasing activity in office portfolio shows positive results | 8 | The group executed 33 leases, accounting for approximately 32,000 square meters of space, representing 9.2% of the office portfolio income. The group provided an average incentive of 24% across the office portfolio leases signed in FY 2023, indicating strong demand for office space.\n\nIndustrial portfolio leasing shows positive growth | 9 | The group leased 124,000 square meters, representing 15.4% of the industrial portfolio income, with a positive average effective rental leasing spread of 30%. This demonstrates strong demand for industrial space and a diverse range of industries leasing from the portfolio.\n\nPortfolio WALE remains strong | 10 | The portfolio WALE reduced slightly over the year from 6.3 years to 6 years, but still retains one of the longest office portfolio WALE in the REIT sector at 6.3 years. This indicates a stable and secure income stream for the group.\n\nHigh average NABERS Energy rating and increased GRESB score | 9 | The portfolio continues to achieve a high average NABERS Energy rating of 5.2 stars and increased its GRESB score to 81, remaining a sector leader. This demonstrates the group's commitment to sustainability and its progress towards its 2025 net zero target.\n\nSolid financial performance with FFO of AUD 0.268 per security | 7 | Despite a slight decrease of 3.2% from last year, this was a good outcome given the rapid increase in interest rates. The group also declared a distribution of AUD 0.214 per security, up 2.9%.\n\nGearing remains within target range | 8 | Gearing increased from 31.6% to 37.2%, but still remains within the group's target range of 35% to 45%. The group also has ample headroom to its bank covenants and a good buffer to withstand any further potential changes in valuations.\n\nWeighted average cost of debt increases due to interest rate rise | -6 | The weighted average cost of debt increased from 3.4% to 4.6% due to the rapid increase in interest rates during the year.\n\nSuccessful execution of new electricity contracts and sustainability linked loans | 9 | The group has made progress towards its 2025 net zero target through the execution of new electricity contracts, including green power purchases. It has also issued its first sustainability linked loans, demonstrating its commitment to sustainability.\n\nDiscount to NTA implies a 25% reduction for both office and industrial portfolios | -8 | The current security price discount to NTA implies a 25% reduction for both the office and industrial portfolios. This is a common theme across the REIT sector, but the defensive characteristics of the group's portfolio make it an attractive investment in a low growth environment.\n\nPortfolio of high quality modern assets with strong WALE and diverse tenant base | 9 | The group's portfolio consists of high quality modern assets with strong WALE from government, ASX listed, and large corporate tenants. This provides stability and security for the group's income stream.\n\nLow commercial real estate transaction activity | -7 | Commercial real estate transaction activity remains low, but the group is well positioned to manage through the cycle with its strong portfolio and prudent management of its balance sheet.",
#  " So we're not seeing\nany real change in the tenant profile that we're attracting to our assets.\nOkay. Got you. And just last one for me, just on the industrial portfolio. So I understand you're\nlooking to sell two assets. But just curious, how do you think about the rest of the portfolio\ngiven the strong demand for industrial assets right now? And do you think there's any\nopportunity to sell more assets in the near term?\nThanks, Solomon. It's Tim here. Look, we're always looking at our portfolio and we're always\nlooking at opportunities to recycle capital. We've got a very strong portfolio of industrial assets\nand we're very happy with the portfolio. But we're always looking at opportunities to recycle\ncapital. So we'll continue to do that. But we're not going to be selling assets just for the sake of\nselling assets. We'll be looking at opportunities to recycle capital and to improve the quality of\nour portfolio. So we'll continue to do that. But we're not going to be selling assets just for the\nsake of selling assets. We'll be looking at opportunities to recycle capital and to improve the\nquality of our portfolio. So we'll continue to do that. But we're not going to be selling assets\njust for the sake of selling assets. We'll be looking at opportunities to recycle capital and to\nimprove the quality of our portfolio. So we'll continue to do that. But we're not going to be\nselling assets just for the sake of selling assets. We'll be looking at opportunities to recycle\ncapital and to improve the quality of our portfolio. So we'll continue to do that. But we're not\ngoing to be selling assets just for the sake of selling assets. We'll be looking at opportunities to\nrecycle capital and to improve the quality of our portfolio. So we'll continue to do that. But\nwe're not going to be selling assets just for the sake of selling assets. We'll be looking at\nopportunities to recycle capital and to improve the quality of our portfolio. So we'll continue to\ndo that. But we're not going to be selling assets just for the sake of selling assets. We'll be\nlooking at opportunities to recycle capital and to improve the quality of our portfolio. So we'll\ncontinue to do that. But we're not going to be selling assets just for the sake of selling assets.\nWe'll be looking at opportunities to recycle capital and to improve the quality of our portfolio.\n\nGrowthpoint provides FFO guidance of between AUD 0.225 and AUD 0.231 per security for financial year 2024 | 8 | This is a positive development as it shows an increase in FFO compared to the previous year. This is due to the outlook and factoring in interest costs on forward. \n\nDistribution guidance of $0.193 per security is provided while maintaining FFO payout ratio in the target range of 75% to 85% at the midpoint of guidance | 7 | This is a positive development as it shows a stable distribution and a commitment to providing sustainable income returns and capital appreciation over the longer term. \n\nFinancial year 2024 distribution yield is an attractive 7.3% | 9 | This is a positive development as it shows a high yield for investors. \n\nTenant exits throughout the year have caused a decrease in office occupancy from 92% in March to 90% as at June | -5 | This is a negative development as it shows a decrease in occupancy, which could potentially lead to a decrease in rental income. \n\nLimited downtime for property space due to strong leasing results | 8 | This is a positive development as it shows the high quality of assets owned by Growthpoint and their ability to attract tenants. \n\n95% of income derived from non-SME tenants | 9 | This is a positive development as it shows a strong portfolio of tenant covenants and limited risk of rent-related issues. \n\nGearing at 37% is considered high compared to peers | -3 | This is a negative development as it shows a higher level of debt compared to peers. \n\nTwo small industrial assets are currently on the market for sale  ...
#  '\n\nEffective basis sort of circa 30% uplift on the effective rents across the industrial portfolio | 8 | The effective rents have seen a significant increase of 30%, indicating strong growth in the industrial sector.\n\nAUD 560 million sale of the Korean pension fund to AustralianSuper and managed portfolio | 10 | This is a significant transaction in the market, showing strong demand for large logistics portfolios.\n\nLiquidity in the retail property market is quite liquid with a large format retail, neighborhood shopping centers, and regional shopping centers trading | 9 | The retail property market is showing strong liquidity, with various types of properties trading.\n\nLess liquidity in the market for industrial properties, but still fairly liquid | 6 | While there is less liquidity compared to other sectors, industrial properties are still trading at a reasonable rate.\n\nOffice sector has a larger bid/ask spread and lower volume of assets | -7 | The office sector is facing challenges with a wider bid/ask spread and lower volume of assets.\n\nConfident about the prospects for the funds management business | 9 | The Australian market is seen as attractive for investors, with a growing population and strong economy.\n\nGuidance ranges reasonably wide due to volatility in interest rates | -5 | The volatility in interest rates makes it difficult to provide a narrow guidance range.\n\nHigher interest rates impacting the funds management business, but strategies in place to manage it | -6 | The funds management business is facing challenges due to higher interest rates, but strategies are being implemented to mitigate the impact.\n\nLow expiries in the next couple of years, but potential for higher expiries in FY 2026 | 5 | While there are low expiries in the near future, there is potential for higher expiries in FY 2026, but with strong tenants such as Woolworths and Linfox, the risk is mitigated.\n\nWoolworths and Linfox are expected to renew their leases, but if not, there is a high likelihood of finding new tenants quickly | 8 | Based on past experience, Woolworths and Linfox are expected to renew their leases, but if not, there is a strong likelihood of finding new tenants quickly.']

# %% [markdown]
# # 3.3 - Formatear la salida
#
# Dividimos aquellas lineas de texto que se encuentran en formato "Evento" | -10 a 10 | "Razón del score" y las almacenamos en un DataFrame de Pandas. Por supuesto, aquellas que no cumplen con las reglas son ignoradas.

# %%
def split_business_development_text(text):
    parts = text.split('|')
    if len(parts) == 3:
        business_development_summary = parts[0].strip()
        score = parts[1].strip()
        reason_for_score = parts[2].strip()
        return business_development_summary, score, reason_for_score
    else:
        print(f'Invalid format for: {text}')
        return None, None, None
    
bd_output_dfs = []
for output in bd_outputs:
    bd_output_dfs.append(DataFrame({'RAW Output': output.split('\n')}))

bd_output_df = pdconcat(bd_output_dfs)
bd_output_df = bd_output_df[bd_output_df["RAW Output"] != '']
bd_output_df = bd_output_df.drop_duplicates(["RAW Output"]).reset_index(drop=True).copy()

#Creamos nuevas columnas
bd_output_df[['Business development', 'Score', 'Explanation']] = bd_output_df['RAW Output'].apply(
    lambda x: pdSeries(split_business_development_text(x))
)
bd_output_df = bd_output_df.dropna()
# Out:
# Invalid format for:  We are proud of
# Invalid format for: achieving a 92% satisfaction rating, which is a testament to our team's focus on tenant
# Invalid format for: engagement.
# Invalid format for: Growthpoint Properties Australia: Q4 2023 Earnings Call
# Invalid format for:  So we're not seeing
# Invalid format for: any real change in the tenant profile that we're attracting to our assets.
# Invalid format for: Okay. Got you. And just last one for me, just on the industrial portfolio. So I understand you're
# Invalid format for: looking to sell two assets. But just curious, how do you think about the rest of the portfolio
# Invalid format for: given the strong demand for industrial assets right now? And do you think there's any
# Invalid format for: opportunity to sell more assets in the near term?
# Invalid format for: Thanks, Solomon. It's Tim here. Look, we're always looking at our portfolio and we're always
# Invalid format for: looking at opportunities to recycle capital. We've got a very strong portfolio of industrial assets
# Invalid format for: and we're very happy with the portfolio. But we're always looking at opportunities to recycle
# Invalid format for: capital. So we'll continue to do that. But we're not going to be selling assets just for the sake of
# Invalid format for: selling assets. We'll be looking at opportunities to recycle capital and to improve the quality of
# Invalid format for: our portfolio. So we'll continue to do that. But we're not going to be selling assets just for the
# Invalid format for: sake of selling assets. We'll be looking at opportunities to recycle capital and to improve the
# Invalid format for: quality of our portfolio. So we'll continue to do that. But we're not going to be selling assets
# Invalid format for: just for the sake of selling assets. We'll be looking at opportunities to recycle capital and to
# Invalid format for: improve the quality of our portfolio. So we'll continue to do that. But we're not going to be
# Invalid format for: selling assets just for the sake of selling assets. We'll be looking at opportunities to recycle
# Invalid format for: capital and to improve the quality of our portfolio. So we'll continue to do that. But we're not
# Invalid format for: going to be selling assets just for the sake of selling assets. We'll be looking at opportunities to
# Invalid format for: recycle capital and to improve the quality of our portfolio. So we'll continue to do that. But
# Invalid format for: we're not going to be selling assets just for the sake of selling assets. We'll be looking at
# Invalid format for: opportunities to recycle capital and to improve the quality of our portfolio. So we'll continue to
# Invalid format for: do that. But we're not going to be selling assets just for the sake of selling assets. We'll be
# Invalid format for: looking at opportunities to recycle capital and to improve the quality of our portfolio. So we'll
# Invalid format for: continue to do that. But we're not going to be selling assets just for the sake of selling assets.
# Invalid format for: We'll be looking at opportunities to recycle capital and to improve the quality of our portfolio.

# %%
bd_output_df
# Out:
#                                            RAW Output  \
# 4   1. Growthpoint's leasing performance was stron...
# 5   2. The group's goal remains to provide securit...
# 6   3. In financial year 2023, Growthpoint purchas...
# 7   4. Capital management remains a sharp focus gi...
# 8   5. The group's property portfolio value decrea...
# 9   6. Despite challenging market conditions, dist...
# 10  7. The positive momentum in the industrial mar...
# 11  8. The acquisition of Fortius Funds Management...
# 12  9. The group's office portfolio is reduced by ...
# 13  10. Tenant engagement is a major focus for Gro...
# 14  11. The company's high quality, energy efficie...
# 15  12. Growthpoint achieved a 92% satisfaction ra...
# 16  Leasing activity in office portfolio shows pos...
# 17  Industrial portfolio leasing shows positive gr...
# 18  Portfolio WALE remains strong | 10 | The portf...
# 19  High average NABERS Energy rating and increase...
# 20  Solid financial performance with FFO of AUD 0....
# 21  Gearing remains within target range | 8 | Gear...
# 22  Weighted average cost of debt increases due to...
# 23  Successful execution of new electricity contra...
# 24  Discount to NTA implies a 25% reduction for bo...
# 25  Portfolio of high quality modern assets with s...
# 26  Low commercial real estate transaction activit...
# 53  Growthpoint provides FFO guidance of between A...
# 54  Distribution guidance of $0.193 per security i...
# 55  Financial year 2024 distribution yield is an a...
# 56  Tenant exits throughout the year have caused a...
# 57  Limited downtime for property space due to str...
# 58  95% of income derived from non-SME tenants | 9...
# 59  Gearing at 37% is considered high compared to ...
# 60  Two small industrial assets are currently on t...
# 61  Growthpoint is always looking for opportunitie...
# 62  Effective basis sort of circa 30% uplift on th...
# 63  AUD 560 million sale of the Korean pension fun...
# 64  Liquidity in the retail property market is qui...
# 65  Less liquidity in the market for industrial pr...
# 66  Office sector has a larger bid/ask spread and ...
# 67  Confident about the prospects for the funds ma...
# 68  Guidance ranges reasonably wide due to volatil...
# 69  Higher interest rates impacting the funds mana...
# 70  Low expiries in the next couple of years, but ...
# 71  Woolworths and Linfox are expected to renew th...
#
#                                  Business development      Score  \
# 4   1. Growthpoint's leasing performance was stron...   Score: 8
# 5   2. The group's goal remains to provide securit...   Score: 9
# 6   3. In financial year 2023, Growthpoint purchas...   Score: 7
# 7   4. Capital management remains a sharp focus gi...   Score: 8
# 8   5. The group's property portfolio value decrea...  Score: -6
# 9   6. Despite challenging market conditions, dist...   Score: 7
# 10  7. The positive momentum in the industrial mar...   Score: 9
# 11  8. The acquisition of Fortius Funds Management...   Score: 9
# 12  9. The group's office portfolio is reduced by ...  Score: -5
# 13  10. Tenant engagement is a major focus for Gro...  Score: 10
# 14  11. The company's high quality, energy efficie...   Score: 9
# 15  12. Growthpoint achieved a 92% satisfaction ra...  Score: 10
# 16  Leasing activity in office portfolio shows pos...          8
# 17  Industrial portfolio leasing shows positive gr...          9
# 18                      Portfolio WALE remains strong         10
# 19  High average NABERS Energy rating and increase...          9
# 20  Solid financial performance with FFO of AUD 0....          7
# 21                Gearing remains within target range          8
# 22  Weighted average cost of debt increases due to...         -6
# 23  Successful execution of new electricity contra...          9
# 24  Discount to NTA implies a 25% reduction for bo...         -8
# 25  Portfolio of high quality modern assets with s...          9
# 26    Low commercial real estate transaction activity         -7
# 53  Growthpoint provides FFO guidance of between A...          8
# 54  Distribution guidance of $0.193 per security i...          7
# 55  Financial year 2024 distribution yield is an a...          9
# 56  Tenant exits throughout the year have caused a...         -5
# 57  Limited downtime for property space due to str...          8
# 58         95% of income derived from non-SME tenants          9
# 59  Gearing at 37% is considered high compared to ...         -3
# 60  Two small industrial assets are currently on t...          5
# 61  Growthpoint is always looking for opportunitie...          7
# 62  Effective basis sort of circa 30% uplift on th...          8
# 63  AUD 560 million sale of the Korean pension fun...         10
# 64  Liquidity in the retail property market is qui...          9
# 65  Less liquidity in the market for industrial pr...          6
# 66  Office sector has a larger bid/ask spread and ...         -7
# 67  Confident about the prospects for the funds ma...          9
# 68  Guidance ranges reasonably wide due to volatil...         -5
# 69  Higher interest rates impacting the funds mana...         -6
# 70  Low expiries in the next couple of years, but ...          5
# 71  Woolworths and Linfox are expected to renew th...          8
#
#                                           Explanation
# 4   This is a positive development as it shows a h...
# 5   This is a very positive development as it show...
# 6   This is a positive development as it shows the...
# 7   This is a positive development as it shows the...
# 8   This is a negative development as it shows a d...
# 9   This is a positive development as it shows the...
# 10  This is a very positive development as it show...
# 11  This is a very positive development as it show...
# 12  This is a negative development as it shows a d...
# 13  This is a very positive development as it show...
# 14  This is a very positive development as it show...
# 15  This is a very positive development as it show...
# 16  The group executed 33 leases, accounting for a...
# 17  The group leased 124,000 square meters, repres...
# 18  The portfolio WALE reduced slightly over the y...
# 19  The portfolio continues to achieve a high aver...
# 20  Despite a slight decrease of 3.2% from last ye...
# 21  Gearing increased from 31.6% to 37.2%, but sti...
# 22  The weighted average cost of debt increased fr...
# 23  The group has made progress towards its 2025 n...
# 24  The current security price discount to NTA imp...
# 25  The group's portfolio consists of high quality...
# 26  Commercial real estate transaction activity re...
# 53  This is a positive development as it shows an ...
# 54  This is a positive development as it shows a s...
# 55  This is a positive development as it shows a h...
# 56  This is a negative development as it shows a d...
# 57  This is a positive development as it shows the...
# 58  This is a positive development as it shows a s...
# 59  This is a negative development as it shows a h...
# 60  This is a neutral development as it shows norm...
# 61  This is a positive development as it shows a p...
# 62  The effective rents have seen a significant in...
# 63  This is a significant transaction in the marke...
# 64  The retail property market is showing strong l...
# 65  While there is less liquidity compared to othe...
# 66  The office sector is facing challenges with a ...
# 67  The Australian market is seen as attractive fo...
# 68  The volatility in interest rates makes it diff...
# 69  The funds management business is facing challe...
# 70  While there are low expiries in the near futur...
# 71  Based on past experience, Woolworths and Linfo...

# %% [markdown]
# ## 3.4 - Comentarios
#
# ### Variabilidad en el formato de los salidas
#
# Es evidente que, incluso aun estableciendo la temperatura del modelo a 0, se generan respuestas en diversos formatos. Por ejemplo:
#
# * Algunas respuestas comienza con listas numeradas
# * Las explicaciones de los scores a veces se presentan directamente y otras empizan como "This is a positive development..."
#
# Para mitigar esta variabilidad y lograr un formato más consistente, tenemos varios opciones:
#
# * Mejorar los prompts
# * Hacer fine-tuning del modelo
#
# En mi opinión, lo que daría mejores resultados es hacer un adecuado fine-tuning del modelo con ejemplos preparados en el formato deseado.
#
# Alternativamente, podríamos considerar volver a ejecutar secciones de texto que no se han formateado según lo previsto. Podríamos usar una configuración de temperatura más alta durante estas ejecuciones y verificar si la salida se alinea con nuestras expectativas.
#
# Salidas Innecesarias (Desviación de las reglas establecidas en el prompt): Como se evidencia, el modelo ocasionalmente genera texto que no sigue las instrucciones que proporcionamos. Afortunadamente, ignoramos estas salidas innecesarias durante el proceso de formateo. Para abordar este problema, deberíamos investigar por qué ocurre esto y explorar mejoras potenciales para evitar tales desviaciones de nuestras pautas en el futuro.
#
#
#
# # 4 - Obtener info mediante preguntas
#
# Esta tarea tiene como objetivo poner en práctica lo que hemos visto en la parte de Retrieval Augmented Generation (RAG). Especificamente, es una tarea de pregunta-respuesta con contexto, donde el contexto se almacena en una base de datos vectorial.
#
# Como elementos relevantes de la misma, utilizaremos:
# * BBDD: Chroma (en memoria RAM)
# * Modelo de embeddings:
# * Modelo de lenguaje
#
# En este caso vamos a preparar una aplicación muy simple, por lo que no vamos a introducir memoria, multi-query u otras de las mejoras que hemos discutido en la seccion de RAG avanzado.

# %% [markdown]
# ## 4.1 - Modelo de embeddings

# %%
from langchain_openai import OpenAIEmbeddings
from os import getenv


openai_embeddings_model = OpenAIEmbeddings(
    model = "text-embedding-3-large",
    openai_api_key = getenv('OPEN_API_KEY', '')
)

# %% [markdown]
# ## 4.2 - BBDD vectorial

# %%
from langchain.docstore.document import Document
from langchain.vectorstores import Chroma

chunks = df["Paragraph"].tolist()

documents = []
for c in chunks:
    doc = Document(page_content=c, metadata={'source': 'local'})
    documents.append(doc)

db = Chroma.from_documents(documents, openai_embeddings_model)

# %% [markdown]
# ## 4.3 - Retrieval
#
# Ahora escribamos la lógica real de la aplicación. Queremos crear una aplicación sencilla que
#
# 1. Tome una pregunta del usuario
# 2. Busque documentos relevantes para esa pregunta
# 3. Pase los documentos recuperados y la pregunta inicial a un LLM
# 4. Devuelva una respuesta
#
# Primero, necesitamos definir nuestra lógica para buscar en los documentos. LangChain define una interfaz Retriever que envuelve un índice que puede devolver Documentos relevantes dado una uery. Su funcionamiento es similar al de db.similarity_search().
#
# El tipo más común de Retriever es el VectorStoreRetriever, que utiliza las capacidades de búsqueda de similitud de un vector store para facilitar la recuperación.

# %%
#Creamos el retriever, que devuelve los k textos más similares a la pregunta
retriever = db.as_retriever(search_type="similarity", search_kwargs={'k': 3})

# %%
#Corremos una pregunta de ejemplo
retrieved_docs = retriever.invoke("Who are the Chief executives in Growth Point Properties?")

# %%
#Documentos recuperados
retrieved_docs
# Out:
# [Document(page_content='\nGood morning, and welcome to Growthpoint Properties Australia full year 2023 results. My\nname is Tim Collyer, Managing Director of Growthpoint. Joining me this morning are Michael', metadata={'source': 'local'}),
#  Document(page_content='\nThe Growthpoint AUD 4.8 billion balance sheet portfolio consists of the modern office and\nindustrial assets, which are principally leased to government listed and large private tenants and\nprovide the bedrock of a resilient cash flow for our securityholders.', metadata={'source': 'local'}),
#  Document(page_content='\nGreen, Chief Investment Officer; and Dion Andrews, Chief Financial Officer. I will start this\nmorning with a brief overview of our results and strategy. Michael will then provide an update on\nour property portfolio followed by Dion, who will give a more detailed review of our financials.', metadata={'source': 'local'})]

# %% [markdown]
# Parece que recupera correctamente la información, la cual se encuentra dividida en 3 párrafos (si bien en el texto original realmente es uno) por los problemas del PDF que hemos comentado anteriormente (no se cargan correctamente los saltos de linea)

# %% [markdown]
# ## 4.4 - Generation
#
# Una vez tenemos los documentos que otorgarán de contexto al LLM, debemos pasarle dicha información dentro de un prompt (junto a la pregunta).

# %%
model = 'gpt-3.5-turbo-instruct'




max_tokens = 1000

llm = OpenAI(openai_api_key=getenv('OPEN_API_KEY', ''),
                 model= model,
                 temperature=0)

llm.max_tokens = max_tokens

# %%
retrieved_docs
# Out:
# [Document(page_content='\nGood morning, and welcome to Growthpoint Properties Australia full year 2023 results. My\nname is Tim Collyer, Managing Director of Growthpoint. Joining me this morning are Michael', metadata={'source': 'local'}),
#  Document(page_content='\nThe Growthpoint AUD 4.8 billion balance sheet portfolio consists of the modern office and\nindustrial assets, which are principally leased to government listed and large private tenants and\nprovide the bedrock of a resilient cash flow for our securityholders.', metadata={'source': 'local'}),
#  Document(page_content='\nGreen, Chief Investment Officer; and Dion Andrews, Chief Financial Officer. I will start this\nmorning with a brief overview of our results and strategy. Michael will then provide an update on\nour property portfolio followed by Dion, who will give a more detailed review of our financials.', metadata={'source': 'local'})]

# %%
# Plantilla específica para Question-Answering
custom_rag_template = """Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer.
Use three sentences maximum and keep the answer as concise as possible.

{context}

Question: {question}

Answer:"""

custom_rag_prompt = PromptTemplate(
    input_variables=['context', 'question'],
    template=custom_rag_template
)

#Crear la cadena LLM simple
qa_chain = LLMChain(llm=llm, prompt = custom_rag_prompt)

# %%
def qa_run(chain, query):
    start_time = time()

    with get_openai_callback() as cb:
        result = chain.run(query)
        print(f'Spent a total of {cb.total_tokens} tokens')

    end_time = time()
    execution_time = end_time - start_time
    print(f'Time taken: {round(execution_time, 2)} seconds')
    return result

context = ''
for i in range (0, len(retrieved_docs)):
    doc = retrieved_docs[i]
    context += f"\nDocument #{i}:"
    context += doc.page_content

#La pregunta
question = "Who are the Chief executives in Growth Point Properties?"

# La query resultante que mandamos al modelo
query = {
    'context': context,
    'question': question
}

qa_run(qa_chain, query)
# Out:
# Spent a total of 246 tokens
# Time taken: 0.86 seconds
# ' Tim Collyer, Michael Green, and Dion Andrews are the Chief executives in Growth Point Properties.'

# %% [markdown]
# ## 4.5 - Comentarios
#
# Podemos incrementar la complejidad de la aplicación añadiendo funcionalidades tales como:
#
# * Streaming. En vez de devolver la respuesta de golpe una vez ha sido generada, podemos ir devolviendola token a token según se genera (similar al comportamiento de Chat-GPT).
# * Memoria. Este sistema está pensado para interacciones puntuales sobre el modelo. No permite una conversación continuada. Para ello, tendriamos que implementar un historial del chat (i.e., una memoria de corto plazo).
# * Fuentes. Si bien para este ejemplo particular no tiene mucho sentido ya que solo hay un documento sobre el cual estamos haciendo preguntas. Podria darse el caso de que queremos extender la funcionalidad de la aplicacion para analizar un documento de una compañia, sino múltiples documentos, en tal caso, estaria bien que el modelo nos indicase cual es el documento (y que parrafos del mismo) ha utilizado para generar su respuesta.
#
# A su vez, si los párrafos fueran muy largos, deberiamos hacer estimaciones del número de tokens para poder ajustar lo mejor posible las queries (similar a las secciones 2 y 3 de este proyecto)
